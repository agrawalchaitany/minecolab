# %% [markdown]
# # 🎮 **Create a Minecraft Server on Google Colab!**
# 🚀 Set up and run your own **Minecraft server** effortlessly!
#
# ---
#
# ## 📌 **How It Works:**
# ✔️ **The script below will initiate your server.**
# ✔️ **First, you'll need to create the server** before running it.
# ✔️ **No worries!** The scripts below will handle most of the setup for you.
#
# 💡 **Want to change the server's region?** Check the instructions below.
#
# ---
#
# ## 🔗 **Original Repository:**
# [GitHub - agrawalchaitany/minecolab](https://github.com/agrawalchaitany/minecolab.git)
#
# ## ⚡ **Modified Version:**
# ✅ **Well-Optimized for Performance**
#
# ---
#
#
#
# ```
# ███╗   ███╗██╗███╗   ██╗███████╗ ██████╗ ██████╗ ██╗      █████╗ ██████╗
# ████╗ ████║██║████╗  ██║██╔════╝██╔════╝██╔═══██╗██║     ██╔══██╗██╔══██╗
# ██╔████╔██║██║██╔██╗ ██║█████╗  ██║     ██║   ██║██║     ███████║██████╔╝
# ██║╚██╔╝██║██║██║╚██╗██║██╔══╝  ██║     ██║   ██║██║     ██╔══██║██╔══██╗
# ██║ ╚═╝ ██║██║██║ ╚████║███████╗╚██████╗╚██████╔╝███████╗██║  ██║██████╔╝
# ╚═╝     ╚═╝╚═╝╚═╝  ╚═══╝╚══════╝ ╚═════╝ ╚═════╝ ╚══════╝╚═╝  ╚═╝╚═════╝
#
# ```
#
# 🎉 **Enjoy your Minecraft server on Google Colab!**

# %% [markdown]
# # 🛠️ **Step 1: Create the Server (First-Time Setup Only)**
# 🚀 **Run this step only once** to set up your server and accept the EULA.
#
# ---
#
# ## 📌 **What This Does:**
# ✔️ Creates your **Minecraft server**
# ✔️ Automatically **accepts the EULA**
# ✔️ Prepares the server for **quick startup**
#
# ---
#
# 🎮 **After this, your server will be ready to launch!** 🚀

# %% [markdown]
# # ⬇️ **Download the Better MC [FABRIC] 1.21.1 v22 Server**
# 🚀 A **high-performance Fabric server** for an enhanced gaming experience!
#
# ---
#
# ## 📌 **About**
# The code below will **download** the **Better MC [FABRIC] 1.21.1 v22** server.
#
# 📂 **Storage Location:**
# The server files will be **saved on your Google Drive**
# (Linked to the Google account you choose or are currently using).
#
# ---
#
# ✅ **Enjoy seamless performance with Fabric!**

# %%
# ============================================
#  Better MC [FABRIC] BMC3
# ============================================
#
#  📌 By: LunaPixelStudios
#  📦 Modpack
#
# ============================================
#  🎮 Game Versions:
#  - 1.21.1
#  - 1.21
#
#  ⚙️ Mod Loaders:
#  - Fabric
#
#  📂 Categories:
#  - Vanilla+
#  - Multiplayer
#  - Combat / PvP
#  - Exploration
#  - Adventure and RPG
#
# ============================================
#  📁 Main File:
#  🔹 BMC3 [FABRIC] 1.21.1 v22
#  📌 Release Type: R
#  🎮 Minecraft Version: 1.21.1
#  ⚙️ Mod Loader: Fabric
#  📅 Release Date: February 17, 2025
#  📦 File Size: 39.71 MB
#  📥 Downloads: 395
#  🔹 File Name: Better MC [FABRIC] 1.21.1 v22.zip
#
#  🔹 Supported Versions:
#  - 1.21.1
#  - 1.21
#
# ============================================



import requests
import json
import os
import shutil
from google.colab import drive

# Mount Google Drive
drive.mount("/content/drive")

# Configuration
MINECRAFT_VERSION = "1.21.1"
SERVER_TYPE = "Better_MC"
SERVER_DIR = "/content/drive/My Drive/Minecraft-server_Better_MC"
os.makedirs(SERVER_DIR, exist_ok=True)


# download URLs
server_urls = {
    "Better_MC": "https://www.curseforge.com/api/v1/mods/826731/files/6202388/download",
}
file_name ={
    "Better_MC": "Better_MC.zip",
}

download_url = server_urls.get(SERVER_TYPE)
zip_file="/content/drive/My Drive/Minecraft-server_Better_MC/Better_MC.zip"
# Download the selected server
if download_url:
    print(f"Downloading {SERVER_TYPE} server from {download_url}...")
    response = requests.get(download_url)

    if response.status_code == 200:
        with open(os.path.join(SERVER_DIR, file_name[SERVER_TYPE]), "wb") as f:
          f.write(response.content)
        shutil.unpack_archive(zip_file, SERVER_DIR)
        print("unzip successfully.")
        print(f"{SERVER_TYPE} server downloaded successfully.")
    else:
        print(f"Failed to download {SERVER_TYPE} server. Status code: {response.status_code}")
else:
    print(f"Invalid server type or missing URL: {SERVER_TYPE}")

os.system("bash start.sh")

# Save configuration
config_data = {"server_type": SERVER_TYPE, "server_version": MINECRAFT_VERSION }
with open(os.path.join(SERVER_DIR, "colabconfig.json"), "w") as config_file:
    json.dump(config_data, config_file)

print("Setup complete!")

# Accept Minecraft EULA
eula_path = os.path.join(SERVER_DIR, "eula.txt")
with open(eula_path, "w") as eula_file:
    eula_file.write("eula=true\n")

print("EULA accepted. Ready to start the server!")
# Out:
# Mounted at /content/drive
# Downloading Better_MC server from https://www.curseforge.com/api/v1/mods/826731/files/6202388/download...
# unzip successfully.
# Better_MC server downloaded successfully.
# Setup complete!
# EULA accepted. Ready to start the server!

# %% [markdown]
# ### 🚀 Starting the Minecraft Server
# 💡 Use this whenever you want to open the server.
#
# ---
#
# ## 🎮 Minecraft Server Configuration
#
# ### 🔧 Edit `server.properties` to Customize Settings:
# ```properties
# difficulty=hard
# max-players=10
# online-mode=false # For cracked servers(For example - Tlauncher)
# server-port=25565 # ⚠️ Must be set
# ```
#
# ---
#
# ### ⚠️ Important Note:
# 🔹 Modify the following line in `variable.txt`:
# ```bash
# JAVA_ARGS="-Xmx8G -Xms4G -XX:+UseG1GC -XX:MaxGCPauseMillis=100 -XX:G1NewSizePercent=20 -XX:G1MaxNewSizePercent=40 -XX:InitiatingHeapOccupancyPercent=35 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC"
# ```

# %%
import os
import time
import json
import re
from google.colab import drive

# 🛠️ Update package lists
print("\n🔄 Updating package lists...")
os.system("sudo apt update &>/dev/null && echo '✅ apt cache successfully updated' || echo '❌ apt cache update failed.'")

# 📂 Mount Google Drive
print("\n🔗 Mounting Google Drive...")
drive.mount('/content/drive')

# 🎮 Change directory to Minecraft server folder
server_path = "/content/drive/My Drive/Minecraft-server_Better_MC"
if os.path.exists(server_path):
    os.chdir(server_path)
    print(f"✅ Changed working directory to: {server_path}")
    print("📂 Listing server files:\n")
    # !ls
else:
    print(f"❌ Error: {server_path} not found. Make sure the folder exists in Google Drive.")
    exit()

# 🔧 Load or create configuration file
config_file = "colabconfig.json"
if os.path.isfile(config_file):
    with open(config_file, "r") as f:
        colabconfig = json.load(f)
else:
    colabconfig = {"server_type": "generic"}
    with open(config_file, "w") as f:
        json.dump(colabconfig, f)

server_type = colabconfig.get("server_type", "generic")


# 🌍 tunneling service availble
#  -nglocalhost
#  -pinggy

# 🌍 Setup tunneling service
tunnel_service = "pinggy"  # Can be changed to "pinggy" if needed
print(f"\n🌍 Using {tunnel_service} for server tunneling...")
key_path = "/content/drive/My Drive/Minecraft-server_Better_MC/ssh_keys/id_rsa"

# ⏳ Generate SSH key if missing.
def generate_ssh_key(key_path):

    if not os.path.isfile(key_path):
        os.makedirs(os.path.dirname(key_path), exist_ok=True)
        os.system(f"ssh-keygen -t rsa -b 4096 -f '{key_path}' -N '' -q")
        os.system(f"chmod 400 '{key_path}'")
        os.system(f"ssh-keygen -lf '{key_path}.pub' > '{key_path}_fingerprint.txt'")

print(f"\n🔌 Setting up {tunnel_service} tunneling...")

# 🔌 Establishing the tunnel
if tunnel_service == "nglocalhost":

    # ⏳ Generate SSH key if missing
    generate_ssh_key(key_path)

    # Establish tunnel
    print("⏳ Establishing tunnel, please wait...")
    os.system("nohup ssh -T -o StrictHostKeyChecking=no -i '/content/drive/My Drive/Minecraft-server_Better_MC/ssh_keys/id_rsa' -R minecraft03127:25565:localhost:25565 nglocalhost.com > tunnel_log.txt 2>&1 &")
    url_pattern=r"(nglocalhost:[^\s]+)"
    # Wait for tunnel to establish
    time.sleep(10)

elif tunnel_service == "pinggy":

    # ⏳ Generate SSH key if missing
    generate_ssh_key(key_path)

    # Establish tunnel
    print("⏳ Establishing tunnel, please wait...")
    os.system("nohup ssh -p 443 -o StrictHostKeyChecking=no -o ServerAliveInterval=30 -R0:127.0.0.1:25565 tcp@ap.a.pinggy.io > tunnel_log.txt 2>&1 &")
    url_pattern=r"(tcp://[^\s]+)"
    # Wait for tunnel to establish
    time.sleep(10)

else:
    print("⚠️ No tunneling service selected. Server will run locally.")

# Extract and display the tunnel URL
with open("tunnel_log.txt", "r") as log_file:
    log_content = log_file.read()
    match = re.search(url_pattern, log_content)  # Extract first URL
    if match:
        tunnel_url = match.group(0)
        print(f"✅ Tunnel established! Access your Minecraft server at:\n🌍 {tunnel_url}")
    else:
        print("⚠️ Could not extract tunnel URL. Check 'tunnel_log.txt' manually.")

# 🚀 Start Minecraft server
print("\n🚀 Starting Minecraft server...")
# !bash start.sh
print("✅ Minecraft server closed!")
# Out:
# 🔄 Updating package lists...
#
# 🔗 Mounting Google Drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Changed working directory to: /content/drive/My Drive/Minecraft-server_Better_MC
# 📂 Listing server files:
#
# banned-ips.json      download_graal.ps1		 ops.json	      start.sh
# banned-players.json  eula.txt			 READ_ME.txt	      tunnel_log.txt
# Better_MC.zip	     fabric-server-launcher.jar  server-icon.png      usercache.json
# colabconfig.json     install_java.ps1		 server.properties    usernamecache.json
# config		     install_java.sh		 ssh_keys	      variables.txt
# configureddefaults   libraries			 stackdeobf_mappings  versions
# crash-reports	     logs			 start.bat	      whitelist.json
# defaultconfigs	     mods			 start.ps1	      world
#
# 🌍 Using pinggy for server tunneling...
#
# 🔌 Setting up pinggy tunneling...
# ⏳ Establishing tunnel, please wait...
# ✅ Tunnel established! Access your Minecraft server at:
# 🌍 tcp://rnyzx-34-86-129-239.a.free.pinggy.link:37029
#
# 🚀 Starting Minecraft server...
# Start script generated by ServerPackCreator 7.2.1.
# To change the launch settings of this server, such as JVM args / flags, Minecraft version, modloader version etc., edit the variables.txt-file.
# WARNING! The current location of this script contains spaces. This may cause this server to crash!
# It is strongly recommended to move this server pack to a location whose path does NOT contain SPACES!
#
# Current path:
# /content/drive/My Drive/Minecraft-server_Better_MC
#
# Are you sure you want to continue? (Yes/No): Yes
# Alrighty. Prepare for unforseen consequences, Mr. Freeman...
# Warning! Running with administrator-privileges is not recommended.
# No suitable Java installation was found on your system. Proceeding to Java installation.
# Downloading and using Java graalvm@1.21.0-4
# Installation finished. Returning to start-script.
#
# Running Fabric checks and setup...
# Improved Fabric Server Launcher available...
# The improved launcher will be used to run this Fabric server.
# fabric-server-launcher.jar present.
#
#
# Starting server...
# Minecraft version:              1.21.1
# Modloader:                      Fabric
# Modloader version:              0.16.10
# LegacyFabric Installer Version: 1.0.0
# Fabric Installer Version:       1.0.1
# Quilt Installer Version:        0.11.1
# Java Args:                      -Xmx11G -Xms8G -XX:+UseG1GC -XX:MaxGCPauseMillis=50 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:SurvivorRatio=8 -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=60
# Additional Args:                -Dlog4j2.formatMsgNoLookups=true
# Java Path:                      java
# Wait For User Input:            true
# Launcher JAR:                   fabric-server-launcher.jar
# Run Command:       java -Dlog4j2.formatMsgNoLookups=true -Xmx11G -Xms8G -XX:+UseG1GC -XX:MaxGCPauseMillis=50 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:SurvivorRatio=8 -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=60 -jar fabric-server-launcher.jar nogui
# Java version:
# java version "21.0.4" 2024-07-16 LTS
# Java(TM) SE Runtime Environment Oracle GraalVM 21.0.4+8.1 (build 21.0.4+8-LTS-jvmci-23.1-b41)
# Java HotSpot(TM) 64-Bit Server VM Oracle GraalVM 21.0.4+8.1 (build 21.0.4+8-LTS-jvmci-23.1-b41, mixed mode, sharing)
#
# Starting net.fabricmc.loader.impl.game.minecraft.BundlerClassPathCapture
# [17:51:00] [main/INFO]: Loading Minecraft 1.21.1 with Fabric Loader 0.16.10
# [17:51:01] [ForkJoinPool-1-worker-2/WARN]: The mod "betterstats" contains invalid entries in its mod json:
# - Unsupported root entry "" at line 26 column 4
# - Unsupported root entry "" at line 26 column 124
# - Unsupported root entry "" at line 28 column 4
# - Unsupported root entry "" at line 28 column 24
# [17:51:01] [ForkJoinPool-1-worker-1/WARN]: The mod "dungeons_arise" contains invalid entries in its mod json:
# - Unsupported root entry "credits" at line 12 column 11
# [17:51:03] [ForkJoinPool-1-worker-2/WARN]: The mod "luna" contains invalid entries in its mod json:
# - Unsupported root entry "credits" at line 10 column 14
# - Unsupported root entry "incompatible" at line 34 column 19
# [17:51:03] [ForkJoinPool-1-worker-2/WARN]: The mod "tcdcommons" contains invalid entries in its mod json:
# - Unsupported root entry "" at line 27 column 4
# - Unsupported root entry "" at line 27 column 198
# - Unsupported root entry "" at line 29 column 4
# - Unsupported root entry "" at line 29 column 24
# [17:51:04] [ForkJoinPool-1-worker-1/WARN]: Mod wither_spawn_fix uses the version MC1.21-1.0.0 which isn't compatible with Loader's extended semantic version format (Could not parse version number component 'MC1'!), SemVer is recommended for reliably evaluating dependencies and prioritizing newer version
# [17:51:04] [main/INFO]: Dependencies overridden for mediumcore, improved-signs
# [17:51:04] [main/WARN]: Warnings were found!
#  - Mod 'Debugify' (debugify) 1.21.1+1.0 recommends any version of modmenu, which is missing!
# 	 - You should install any version of modmenu for the optimal experience.
#  - Mod 'Forge Config API Port' (forgeconfigapiport) 21.1.3 recommends any version of modmenu, which is missing!
# 	 - You should install any version of modmenu for the optimal experience.
#  - Mod 'Reacharound' (reacharound) 1.3.1 recommends any version of modmenu, which is missing!
# 	 - You should install any version of modmenu for the optimal experience.
# [17:51:04] [main/INFO]: Loading 383 mods:
# 	- accessories 1.1.0-beta.28+1.21.1
# 	- accessorify 1.3.1+1.21.1
# 	   |-- com_moulberry_mixinconstraints 1.0.1
# 	   \-- mixinsquared 0.2.0
# 	- adorabuild_structures 2.8.0
# 	- advancednetherite 2.2.1-1.21.1
# 	- adventuredungeons 1.3.1
# 	- adventurez 1.4.24
# 	- aether 1.5.4
# 	   |-- cumulus_menus 2.0.0
# 	   |    \-- mixinextras 0.5.0-beta.3
# 	   |-- mixinextras 0.5.0-beta.3
# 	   |-- mm_shedaniel 2.4.1
# 	   \-- nitrogen_internals 1.1.21
# 	- aether_villages 1.0.8
# 	- almanac 1.0.2
# 	- alternate-current 1.9.0
# 	- amendments 1.21-1.2.23
# 	- animal_feeding_trough 1.1.2+1.21.1
# 	- another_furniture 4.0.0
# 	- architectury 13.0.8
# 	- athena 4.0.1
# 	- aurelj_paintings 1.0.4
# 	- autochefsdelight 2.0.2+fabric
# 	- balm-fabric 21.0.28
# 	   \-- kuma_api 21.0.5-SNAPSHOT
# 	- barteringstation 21.1.0
# 	- bcc 21.1.0
# 	- bclib 21.0.13
# 	- betterdungeons 1.21.1-Fabric-5.1.4
# 	   \-- org_reflections_reflections 0.10.2
# 	- betterend 21.0.11
# 	- betterend-crashed-ships 1.1.0
# 	- betterendelytrafix 1.0.0
# 	- betterendisland 1.21.1-Fabric-3.1.1
# 	   \-- org_reflections_reflections 0.10.2
# 	- betterfortresses 1.21.1-Fabric-3.1.3
# 	   \-- org_reflections_reflections 0.10.2
# 	- betterjungletemples 1.21.1-Fabric-3.1.2
# 	   \-- org_reflections_reflections 0.10.2
# 	- bettermineshafts 1.21.1-Fabric-5.1.1
# 	   \-- org_reflections_reflections 0.10.2
# 	- betternether 21.0.11
# 	- betteroceanmonuments 1.21.1-Fabric-4.1.2
# 	   \-- org_reflections_reflections 0.10.2
# 	- betterstats 3.13.8+fabric-1.21
# 	- betterstrongholds 1.21.1-Fabric-5.1.2
# 	   \-- org_reflections_reflections 0.10.2
# 	- betterwitchhuts 1.21.1-Fabric-4.1.1
# 	   \-- org_reflections_reflections 0.10.2
# 	- biomemusic 1.21-3.4
# 	- biomesoplenty 21.1.0.8
# 	- blended_compat 1.1.0
# 	- boatbreakfix 1.0.2
# 	- bookshelf 21.1.48
# 	- bosses_of_mass_destruction 1.10.2-1.21.1
# 	   \-- multipart_entities 1.7-1.21
# 	- cardinal-components 6.1.1
# 	   |-- cardinal-components-base 6.1.1
# 	   |-- cardinal-components-block 6.1.1
# 	   |-- cardinal-components-chunk 6.1.1
# 	   |-- cardinal-components-entity 6.1.1
# 	   |-- cardinal-components-item 6.1.1
# 	   |-- cardinal-components-level 6.1.1
# 	   |-- cardinal-components-scoreboard 6.1.1
# 	   \-- cardinal-components-world 6.1.1
# 	- carryon 2.2.2
# 	- charm 7.0.42-forked
# 	   |-- com_electronwill_night-config_core 3.8.1
# 	   |-- com_electronwill_night-config_toml 3.8.1
# 	   \-- com_moandjiezana_toml_toml4j 0.7.2
# 	- chipped 4.0.2
# 	- chunkactivitytracker 1.0.1
# 	- chunksending 1.21-2.8
# 	- clientcrafting 1.21-1.8
# 	- cloth-config 15.0.140
# 	   \-- cloth-basic-math 0.6.1
# 	- clumps 19.0.0.1
# 	- collective 7.91
# 	- comforts 9.0.3+1.21.1
# 	   \-- spectrelib 0.17.2+1.21
# 	- configurable 2.2.3
# 	- configureddefaults 21.1.3
# 	- connectivity 1.21-6.9
# 	- coroutil 1.21.0-1.3.7
# 	- crash_assistant 1.3.8
# 	- craterlib 2.1.3
# 	- crawl 0.13.0
# 	- cupboard 1.21-2.9
# 	- debugify 1.21.1+1.0
# 	- deeperdarker 1.3.3
# 	- despawntweaks 1.0.0
# 	- deuf_refabricated 1.1.0
# 	- diagonalfences 21.1.1
# 	- diagonalwalls 21.1.2
# 	   \-- diagonalblocks 21.1.2
# 	- diagonalwindows 21.1.1
# 	- does_it_tick 1.1.0
# 	- doubledoors 6.1
# 	- dragonloot 1.1.7
# 	- dummmmmmy 1.21-2.0.6
# 	- dungeons_arise 2.1.60
# 	- easyanvils 21.1.0
# 	- easymagic 21.1.0
# 	- explorations 1.21-1.6.1
# 	- explorify 1.6.2
# 	- fabric-api 0.115.0+1.21.1
# 	   |-- fabric-api-base 0.4.42+6573ed8c19
# 	   |-- fabric-api-lookup-api-v1 1.6.70+b559734419
# 	   |-- fabric-biome-api-v1 13.0.31+d527f9fd19
# 	   |-- fabric-block-api-v1 1.0.22+0af3f5a719
# 	   |-- fabric-block-view-api-v2 1.0.10+6573ed8c19
# 	   |-- fabric-blockrenderlayer-v1 1.1.52+0af3f5a719
# 	   |-- fabric-client-tags-api-v1 1.1.15+6573ed8c19
# 	   |-- fabric-command-api-v1 1.2.49+f71b366f19
# 	   |-- fabric-command-api-v2 2.2.28+6ced4dd919
# 	   |-- fabric-commands-v0 0.2.66+df3654b319
# 	   |-- fabric-content-registries-v0 8.0.18+b559734419
# 	   |-- fabric-convention-tags-v1 2.1.2+7f945d5b19
# 	   |-- fabric-convention-tags-v2 2.9.2+e60e56d419
# 	   |-- fabric-crash-report-info-v1 0.2.29+0af3f5a719
# 	   |-- fabric-data-attachment-api-v1 1.4.1+9ed317f519
# 	   |-- fabric-data-generation-api-v1 20.2.25+16c4ae2519
# 	   |-- fabric-dimensions-v1 4.0.0+6fc22b9919
# 	   |-- fabric-entity-events-v1 1.7.0+2122d82819
# 	   |-- fabric-events-interaction-v0 0.7.13+ba9dae0619
# 	   |-- fabric-game-rule-api-v1 1.0.53+6ced4dd919
# 	   |-- fabric-item-api-v1 11.1.1+d5debaed19
# 	   |-- fabric-item-group-api-v1 4.1.6+6823f7cd19
# 	   |-- fabric-key-binding-api-v1 1.0.47+0af3f5a719
# 	   |-- fabric-keybindings-v0 0.2.45+df3654b319
# 	   |-- fabric-lifecycle-events-v1 2.5.0+01d9a51c19
# 	   |-- fabric-loot-api-v2 3.0.15+3f89f5a519
# 	   |-- fabric-loot-api-v3 1.0.3+3f89f5a519
# 	   |-- fabric-message-api-v1 6.0.13+6573ed8c19
# 	   |-- fabric-model-loading-api-v1 2.0.0+fe474d6b19
# 	   |-- fabric-networking-api-v1 4.3.0+c7469b2119
# 	   |-- fabric-object-builder-api-v1 15.2.1+40875a9319
# 	   |-- fabric-particles-v1 4.0.2+6573ed8c19
# 	   |-- fabric-recipe-api-v1 5.0.14+248df81c19
# 	   |-- fabric-registry-sync-v0 5.2.0+34f5d91419
# 	   |-- fabric-renderer-api-v1 3.4.0+c705a49c19
# 	   |-- fabric-renderer-indigo 1.7.0+c705a49c19
# 	   |-- fabric-renderer-registries-v1 3.2.68+df3654b319
# 	   |-- fabric-rendering-data-attachment-v1 0.3.48+73761d2e19
# 	   |-- fabric-rendering-fluids-v1 3.1.6+1daea21519
# 	   |-- fabric-rendering-v0 1.1.71+df3654b319
# 	   |-- fabric-rendering-v1 5.0.5+df16efd019
# 	   |-- fabric-resource-conditions-api-v1 4.3.0+8dc279b119
# 	   |-- fabric-resource-loader-v0 1.3.1+5b5275af19
# 	   |-- fabric-screen-api-v1 2.0.25+8b68f1c719
# 	   |-- fabric-screen-handler-api-v1 1.3.88+b559734419
# 	   |-- fabric-sound-api-v1 1.0.23+6573ed8c19
# 	   |-- fabric-transfer-api-v1 5.4.2+c24bd99419
# 	   \-- fabric-transitive-access-wideners-v1 6.2.0+45b9699719
# 	- fabric-language-kotlin 1.13.1+kotlin.2.1.10
# 	   |-- org_jetbrains_kotlin_kotlin-reflect 2.1.10
# 	   |-- org_jetbrains_kotlin_kotlin-stdlib 2.1.10
# 	   |-- org_jetbrains_kotlin_kotlin-stdlib-jdk7 2.1.10
# 	   |-- org_jetbrains_kotlin_kotlin-stdlib-jdk8 2.1.10
# 	   |-- org_jetbrains_kotlinx_atomicfu-jvm 0.27.0
# 	   |-- org_jetbrains_kotlinx_kotlinx-coroutines-core-jvm 1.10.1
# 	   |-- org_jetbrains_kotlinx_kotlinx-coroutines-jdk8 1.10.1
# 	   |-- org_jetbrains_kotlinx_kotlinx-datetime-jvm 0.6.1
# 	   |-- org_jetbrains_kotlinx_kotlinx-io-bytestring-jvm 0.6.0
# 	   |-- org_jetbrains_kotlinx_kotlinx-io-core-jvm 0.6.0
# 	   |-- org_jetbrains_kotlinx_kotlinx-serialization-cbor-jvm 1.8.0
# 	   |-- org_jetbrains_kotlinx_kotlinx-serialization-core-jvm 1.8.0
# 	   \-- org_jetbrains_kotlinx_kotlinx-serialization-json-jvm 1.8.0
# 	- fabricloader 0.16.10
# 	- fallingtree 1.21.1.4
# 	- farmers_structures 1.0.0
# 	- farmersdelight 1.21.1-2.3.0+refabricated
# 	   |-- mm 2.3
# 	   |-- porting_lib_base 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- mm 2.3
# 	   |    |-- porting_lib_accessors 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_asm 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_attributes 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_blocks 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_common 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_core 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_entity 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_extensions 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_fluids 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_gametest 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_gui_utils 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_level_events 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_mixin_extensions 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_tags 3.0
# 	   |    \-- porting_lib_transfer 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |-- porting_lib_config 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_core 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    \-- porting_lib_gametest 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |-- porting_lib_item_abilities 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_blocks 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_core 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_gametest 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    \-- porting_lib_level_events 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |-- porting_lib_lazy_registration 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_core 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    \-- porting_lib_gametest 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |-- porting_lib_loot 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_conditions 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    |-- porting_lib_core 3.1.0-beta.47.hotfix.2+1.21.1
# 	   |    \-- porting_lib_gametest 3.1.0-beta.47.hotfix.2+1.21.1
# 	   \-- porting_lib_recipe_book_categories 3.1.0-beta.47.hotfix.2+1.21.1
# 	        |-- porting_lib_core 3.1.0-beta.47.hotfix.2+1.21.1
# 	        \-- porting_lib_gametest 3.1.0-beta.47.hotfix.2+1.21.1
# 	- fastasyncworldsave 1.21-2.3
# 	- faster-random 5.1.0
# 	- fastpaintings 1.21-1.2.15
# 	- faux-custom-entity-data 13.0.1
# 	- featurerecycler 2.0.0
# 	- ferritecore 7.0.2-hotfix
# 	- forgeconfigapiport 21.1.3
# 	- formations 1.0.2
# 	- formationsnether 1.0.5
# 	- formationsoverworld 1.0.4
# 	- framework 0.9.4
# 	   |-- org_javassist_javassist 3.29.2-GA
# 	   \-- org_reflections_reflections 0.10.2
# 	- friendsandfoes 3.0.7
# 	- frostiful 2.1
# 	- ftbfiltersystem 21.0.0
# 	- ftblibrary 2101.1.9
# 	- ftbquests 2101.1.5
# 	   \-- team_reborn_energy 4.1.0
# 	- ftbteams 2101.1.2
# 	- ftbxmodcompat 21.1.2
# 	- fullstackwatchdog 1.0.1+1.19.2-fabric
# 	- fwaystones 3.3.4+mc1.21.1
# 	- geckolib 4.7.3
# 	- geophilic 3.2
# 	- glitchcore 2.1.0.0
# 	   \-- net_jodah_typetools 0.6.3
# 	- grassoverhaul 1.0.0
# 	- handcrafted 4.0.2
# 	- hearths 1.0.2
# 	- iceberg 1.2.9.2
# 	- illagerinvasion 21.1.3
# 	   \-- extensibleenums 21.1.1
# 	- immersivelanterns 1.0.6
# 	- immersivemessages 1.0.16
# 	   \-- mm 2.3
# 	- improved_village_placement 1.0.0
# 	- inmis 2.8.1-1.21.1
# 	- items_displayed 1.3
# 	- jade 15.9.2+fabric
# 	- jamlib 1.2.2-build.2+1.21.1
# 	   \-- blue_endless_jankson 1.2.3
# 	- java 21
# 	- jei 19.21.0.247
# 	- justenoughbreeding 1.5.0
# 	- kiwi 15.1.4+fabric
# 	- kleeslabs 21.1.3
# 	- konkrete 1.9.9
# 	- krypton 0.2.8
# 	   \-- com_velocitypowered_velocity-native 3.3.0-SNAPSHOT
# 	- leavesbegone 21.1.0
# 	- lithium 0.14.7+mc1.21.1
# 	- lithostitched 1.4.2
# 	- lmft 1.0.4+1.21
# 	- logbegone 1.0.3
# 	- lootintegration_wda 1
# 	- lootintegrations 1.21-4.0
# 	- lootintegrations_formations 1
# 	- lootintegrations_moog 1
# 	- lootintegrations_yungs 1
# 	- luna 1.0.0
# 	- magnumtorch 21.1.0
# 	- melody 1.0.10
# 	- memorysettings 1.21-5.9
# 	- mes 1.3.5-1.21-fabric
# 	- midnightlib 1.6.8
# 	- minecraft 1.21.1
# 	- mixintrace 1.1.1+1.17
# 	- mns 1.0.8-1.21-fabric
# 	- modernfix 5.20.2+mc1.21.1
# 	- modpack-update-checker 0.15.4
# 	   \-- mpuc_lavendermd 0.1.2
# 	- moonlight 1.21-2.17.26
# 	- morevillagers 5.1.0
# 	- mr_dungeons_andtavernsancientcityoverhaul 1-v2
# 	- mr_dungeons_andtavernsswamphutoverhaul 1-v2
# 	- mr_dungeons_andtavernswoodlandmansionreplacement 1-v1.2
# 	- mr_farmers_cuttingbiomesoplenty 1.21-2.0.0-fabric
# 	- mr_lukis_crazychambers 1.0
# 	- mvs 4.2.8-1.21-fabric
# 	- mynethersdelight 1.21.1-1.1.2+1.7.7.refabricated
# 	- natures_spirit 2.2.1-1.21.1
# 	- naturescompass 1.21.1-2.2.7-fabric
# 	- necronomicon 1.6.0
# 	- neruina 2.2.8
# 	   |-- com_fasterxml_jackson_core_jackson-annotations 2.17.0
# 	   |-- com_fasterxml_jackson_core_jackson-core 2.17.0
# 	   |-- com_fasterxml_jackson_core_jackson-databind 2.17.0
# 	   |-- org_apache_httpcomponents_core5_httpcore5 5.3.1
# 	   |-- org_apache_maven_maven-artifact 3.8.1
# 	   \-- org_kohsuke_github-api 1.318
# 	- netherchested 21.1.0
# 	   \-- limitlesscontainers 21.1.0
# 	- netherportalfix 21.1.1
# 	- nochatreports 1.21.1-v2.9.1
# 	- noisium 2.3.0+mc1.21-1.21.1
# 	- opacpvp 1.0.0
# 	- openpartiesandclaims 0.23.7
# 	- owo 0.12.15+1.21
# 	   |-- io_wispforest_endec 0.1.5
# 	   |-- io_wispforest_endec_gson 0.1.3
# 	   |-- io_wispforest_endec_jankson 0.1.3
# 	   \-- io_wispforest_endec_netty 0.1.2
# 	- packanalytics 1.0.3
# 	- packetfixer 2.1.0
# 	- paradise_lost 2.3.1-beta+1.21.0
# 	   \-- customportalapi 0.0.1-beta67-1.21
# 	- paxi 1.21.1-Fabric-5.1.2
# 	   \-- org_reflections_reflections 0.10.2
# 	- ping-wheel 1.10.1
# 	- placeholder-api 2.4.2+1.21
# 	- polymorph 1.0.7+1.21.1
# 	- prickle 21.1.6
# 	- puzzleslib 21.1.27
# 	- questkilltask 0.1.0+1.21.1
# 	- reacharound 1.3.1
# 	- recipeessentials 1.21-4.0
# 	- redirected 1.0.0
# 	- repurposed_structures 7.5.13+1.21.1-fabric
# 	- reputation 0.2.9+jade.1.21.1
# 	- resourcefulconfig 3.0.9
# 	- resourcefullib 3.0.11
# 	   |-- com_teamresourceful_bytecodecs 1.1.2
# 	   \-- com_teamresourceful_yabn 1.0.3
# 	- rightclickharvest 4.5.0+1.21.1
# 	- sawmill 1.21-1.5.14
# 	- scalablelux 0.1.0+fabric.26c6e72
# 	- seasons 2.4.2-BETA+1.21
# 	- seasonsdelightcompat 1.0-1.3.9
# 	- seasonsextras 1.3.2-BETA+1.21
# 	- simplemod 1.21.1
# 	- skinlayers3d 1.7.4
# 	- smarterfarmers 1.21-2.2.2
# 	- smoothchunk 1.21-4.0
# 	- snowrealmagic 11.0.13+fabric
# 	- sodiumleafculling 1.0.0
# 	- sound_physics_remastered 1.21.1-1.4.8
# 	- spark 1.10.109
# 	   \-- fabric-permissions-api-v0 0.3.1
# 	- sparsestructures 2.2.0
# 	- stackdeobfuscator 1.4.3+08e71cc
# 	   |-- net_fabricmc_mapping-io 0.6.1
# 	   \-- stackdeobfuscator-common 1.4.3+08e71cc
# 	- stoneworks 21.1.0
# 	- stonycliffs 1.1.2
# 	- structory 1.3.9
# 	- structory_towers 1.0.10
# 	- structure_layout_optimizer 1.0.10
# 	- structureessentials 1.21-4.2
# 	- supplementaries 1.21-3.0.35-beta
# 	- takesapillage 1.0.5
# 	- tcdcommons 3.12.5+fabric-1.21
# 	- tclayer 3.10.0+beta.19
# 	- terrablender 4.1.0.8
# 	- the_bumblezone 7.7.17+1.21.1-fabric
# 	- thermoo 4.3
# 	- thermoo-patches 3.5.1
# 	- toms_storage 2.1.2
# 	- toofast 1.3.0
# 	- tradingpost 21.1.0
# 	- txnilib 1.0.21
# 	- u_desert 1.5.0
# 	- u_framework 1.1.0
# 	- variantcraftingtables 7.1
# 	- variantsandventures 1.0.10
# 	- veinmining 5.0.0-beta+1.21
# 	- villagernames 4.5.4
# 	- villagesandpillages 1.0.2
# 	- visualworkbench 21.1.0
# 	- voidz 1.0.11
# 	- watut 1.21.0-1.1.3
# 	- wither_spawn_fix MC1.21-1.0.0
# 	- wover 21.0.13
# 	   |-- wover-biome 21.0.13
# 	   |-- wover-block 21.0.13
# 	   |-- wover-common 21.0.13
# 	   |-- wover-core 21.0.13
# 	   |-- wover-datagen 21.0.13
# 	   |-- wover-events 21.0.13
# 	   |-- wover-feature 21.0.13
# 	   |-- wover-generator 21.0.13
# 	   |-- wover-item 21.0.13
# 	   |-- wover-math 21.0.13
# 	   |-- wover-preset 21.0.13
# 	   |-- wover-recipe 21.0.13
# 	   |-- wover-structure 21.0.13
# 	   |-- wover-surface 21.0.13
# 	   |-- wover-tag 21.0.13
# 	   \-- wover-ui 21.0.13
# 	- wunderlib 21.0.8
# 	- xaerominimap 25.1.0
# 	- xaeroworldmap 1.39.2
# 	- xp_storage 1.6+1.21
# 	- xp_storage_trinkets 1.0.2+1.21
# 	- yet_another_config_lib_v3 3.6.2+1.21-fabric
# 	   |-- com_twelvemonkeys_common_common-image 3.12.0
# 	   |-- com_twelvemonkeys_common_common-io 3.12.0
# 	   |-- com_twelvemonkeys_common_common-lang 3.12.0
# 	   |-- com_twelvemonkeys_imageio_imageio-core 3.12.0
# 	   |-- com_twelvemonkeys_imageio_imageio-metadata 3.12.0
# 	   |-- com_twelvemonkeys_imageio_imageio-webp 3.12.0
# 	   |-- org_quiltmc_parsers_gson 0.2.1
# 	   \-- org_quiltmc_parsers_json 0.2.1
# 	- yigd 2.4.14
# 	   |-- fabric-permissions-api-v0 0.3.1
# 	   \-- libgui 11.1.0+1.21
# 	        |-- jankson 8.0.0+j1.2.3
# 	        |    \-- blue_endless_jankson 1.2.3
# 	        \-- libninepatch 1.2.0
# 	- ysns 1.0.6
# 	- yungsapi 1.21.1-Fabric-5.1.3
# 	   |-- org_javassist_javassist 3.29.2-GA
# 	   \-- org_reflections_reflections 0.10.2
# 	- yungsbridges 1.21.1-Fabric-5.1.1
# 	   \-- org_reflections_reflections 0.10.2
# [17:51:07] [main/INFO]: Applying default files...
# [17:51:09] [main/INFO]: SpongePowered MIXIN Subsystem Version=0.8.7 Source=file:/content/drive/My%20Drive/Minecraft-server_Better_MC/libraries/net/fabricmc/sponge-mixin/0.15.4+mixin.0.8.7/sponge-mixin-0.15.4+mixin.0.8.7.jar Service=Knot/Fabric Env=SERVER
# [17:51:09] [main/INFO]: Compatibility level set to JAVA_17
# [17:51:09] [main/INFO]: Compatibility level set to JAVA_21
# [17:51:10] [main/WARN]: Reference map 'aether_villages-common-common-refmap.json' for aether_villages.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:10] [main/WARN]: Reference map 'aurelj_paintings-common-common-refmap.json' for aurelj_paintings.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:10] [main/WARN]: Reference map 'barteringstation.fabric.refmap.json' for barteringstation.fabric.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/INFO]: Adding debug check: svenhjol.charm.mixin.MixinConfig$$Lambda/0x00007fc0d026a090@d8d9199
# [17:51:11] [main/INFO]: Adding mixin disable check: svenhjol.charm.mixin.MixinConfig$$Lambda/0x00007fc0d026a4a8@602ae7b6
# [17:51:11] [main/WARN]: Reference map 'configureddefaults.common.refmap.json' for configureddefaults.common.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/WARN]: Reference map 'configureddefaults.fabric.refmap.json' for configureddefaults.fabric.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/WARN]: Reference map 'coroutil.refmap.json' for coroutil_fabric.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/WARN]: Reference map 'diagonalfences.common.refmap.json' for diagonalfences.common.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/WARN]: Reference map 'diagonalfences.fabric.refmap.json' for diagonalfences.fabric.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/WARN]: Reference map 'diagonalwalls.common.refmap.json' for diagonalwalls.common.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/WARN]: Reference map 'diagonalwalls.fabric.refmap.json' for diagonalwalls.fabric.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/WARN]: Reference map 'diagonalwindows.common.refmap.json' for diagonalwindows.common.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/WARN]: Reference map 'diagonalwindows.fabric.refmap.json' for diagonalwindows.fabric.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/WARN]: Reference map 'extensibleenums.common.refmap.json' for extensibleenums.common.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/WARN]: Reference map 'extensibleenums.fabric.refmap.json' for extensibleenums.fabric.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/WARN]: Reference map 'forgeconfigapiport.common.refmap.json' for forgeconfigapiport.common.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/WARN]: Reference map 'formationsnether.mixins.refmap.json' for formationsnether.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/WARN]: Reference map 'formationsoverworld.mixins.refmap.json' for formationsoverworld.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/WARN]: Reference map 'illagerinvasion.fabric.refmap.json' for illagerinvasion.fabric.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/WARN]: Reference map 'leavesbegone.fabric.refmap.json' for leavesbegone.fabric.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/WARN]: Reference map 'limitlesscontainers.common.refmap.json' for limitlesscontainers.common.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/WARN]: Reference map 'limitlesscontainers.fabric.refmap.json' for limitlesscontainers.fabric.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:11] [main/WARN]: No configuration key exists with name 'mixin.ai.nearby_entity_tracking', ignoring
# [17:51:11] [main/WARN]: Mod 'ferritecore' attempted to override option 'mixin.alloc.blockstate', which doesn't exist, ignoring
# [17:51:11] [main/WARN]: Mod 'supplementaries' attempted to override option 'mixins.block.moving_block_shapes', which doesn't exist, ignoring
# [17:51:11] [main/INFO]: Option 'mixin.entity.collisions.fluid' requires 'mixin.util.block_tracking=true' but found 'false'. Setting 'mixin.entity.collisions.fluid=false'.
# [17:51:11] [main/INFO]: Option 'mixin.experimental.entity.block_caching.suffocation' requires 'mixin.util.block_tracking=true' but found 'false'. Setting 'mixin.experimental.entity.block_caching.suffocation=false'.
# [17:51:11] [main/INFO]: Option 'mixin.experimental.entity.block_caching.block_support' requires 'mixin.util.block_tracking=true' but found 'false'. Setting 'mixin.experimental.entity.block_caching.block_support=false'.
# [17:51:11] [main/INFO]: Option 'mixin.experimental.entity.block_caching.fluid_pushing' requires 'mixin.util.block_tracking=true' but found 'false'. Setting 'mixin.experimental.entity.block_caching.fluid_pushing=false'.
# [17:51:11] [main/INFO]: Option 'mixin.experimental.entity.block_caching.block_touching' requires 'mixin.util.block_tracking=true' but found 'false'. Setting 'mixin.experimental.entity.block_caching.block_touching=false'.
# [17:51:11] [main/INFO]: Option 'mixin.experimental.entity.block_caching' requires 'mixin.util.block_tracking=true' but found 'false'. Setting 'mixin.experimental.entity.block_caching=false'.
# [17:51:11] [main/INFO]: Loaded configuration file for Lithium: 144 options available, 2 override(s) found
# [17:51:11] [main/WARN]: Reference map 'magnumtorch.common.refmap.json' for magnumtorch.common.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:12] [main/INFO]: Started MM (shedaniel's fork) at me/shedaniel/gen/mixin/
# [17:51:12] [main/WARN]: Reference map 'Manningham Mills-refmap.json' for mixins.mm_shedaniel.json could not be read. If this is a development environment you can ignore this message
# [17:51:12] [main/INFO]: Loaded configuration file for ModernFix 5.20.2+mc1.21.1: 57 options available, 2 override(s) found
# [17:51:12] [main/WARN]: Option 'mixin.perf.faster_item_rendering' overriden (by user configuration) to 'true'
# [17:51:12] [main/WARN]: Option 'mixin.perf.dynamic_resources' overriden (by user configuration) to 'true'
# [17:51:12] [main/INFO]: Applying Nashorn fix
# [17:51:12] [main/WARN]: Reference map 'netherchested.fabric.refmap.json' for netherchested.fabric.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:12] [main/WARN]: Reference map 'prickle.refmap.json' for prickle.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:12] [main/WARN]: Reference map 'prickle.refmap.json' for prickle.fabric.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:12] [main/WARN]: Reference map 'stoneworks.common.refmap.json' for stoneworks.common.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:12] [main/WARN]: Reference map 'stoneworks.fabric.refmap.json' for stoneworks.fabric.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:12] [main/WARN]: Reference map 'tradingpost.fabric.refmap.json' for tradingpost.fabric.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:12] [main/WARN]: Reference map 'visualworkbench.fabric.refmap.json' for visualworkbench.fabric.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:51:13] [main/WARN]: Error loading class: net/minecraft/class_881 (java.lang.ClassNotFoundException: net/minecraft/class_881)
# [17:51:13] [main/WARN]: @Mixin target net.minecraft.class_881 was not found porting_lib_base.mixins.json:client.BoatRendererMixin from mod porting_lib_base
# [17:51:13] [main/WARN]: Error loading class: net/minecraft/class_525 (java.lang.ClassNotFoundException: net/minecraft/class_525)
# [17:51:13] [main/WARN]: @Mixin target net.minecraft.class_525 was not found porting_lib_base.mixins.json:client.CreateWorldScreenMixin from mod porting_lib_base
# [17:51:13] [main/WARN]: Error loading class: net/minecraft/class_906 (java.lang.ClassNotFoundException: net/minecraft/class_906)
# [17:51:13] [main/WARN]: @Mixin target net.minecraft.class_906 was not found porting_lib_item_abilities.mixins.json:FishingHookRendererMixin from mod porting_lib_item_abilities
# [17:51:13] [main/WARN]: Error loading class: shcm/shsupercm/fabric/citresewn/defaults/cit/types/TypeElytra$Container (java.lang.ClassNotFoundException: shcm/shsupercm/fabric/citresewn/defaults/cit/types/TypeElytra$Container)
# [17:51:13] [main/WARN]: @Mixin target shcm.shsupercm.fabric.citresewn.defaults.cit.types.TypeElytra$Container was not found accessorify.mixins.json:compat.citresewn.TypeElytraContainerMixin from mod accessorify
# [17:51:13] [main/WARN]: Error loading class: net/minecraft/class_310 (java.lang.ClassNotFoundException: net/minecraft/class_310)
# [17:51:13] [main/WARN]: @Mixin target net.minecraft.class_310 was not found aether.mixins.json:client.accessor.MinecraftAccessor from mod aether
# [17:51:15] [main/WARN]: Blacklisted mixin svenhjol.charm.mixin.feature.pigs_find_mushrooms.PigMixin
# [17:51:15] [main/WARN]: Error loading class: dev/ftb/mods/ftbchunks/data/ClaimedChunkManagerImpl (java.lang.ClassNotFoundException: dev/ftb/mods/ftbchunks/data/ClaimedChunkManagerImpl)
# [17:51:15] [main/WARN]: @Mixin target dev.ftb.mods.ftbchunks.data.ClaimedChunkManagerImpl was not found mixins.does_it_tick.json:ClaimedChunkManagerAccessor from mod does_it_tick
# [17:51:16] [main/INFO]: Loading Faster Random.
# [17:51:16] [main/INFO]: Force-disabling mixin 'block.moving_block_shapes.PistonMovingBlockEntityMixin' as rule 'mixin.block.moving_block_shapes' (added by mods [supplementaries]) disables it and children
# [17:51:16] [main/INFO]: Force-disabling mixin 'block.moving_block_shapes.VoxelShapeMixin' as rule 'mixin.block.moving_block_shapes' (added by mods [supplementaries]) disables it and children
# [17:51:16] [main/INFO]: Force-enabling mixin 'compat.transfer_api.TransferApiHelperMixin' as rule 'mixin.compat.transfer_api' (added by mods [lithium]) enables it
# [17:51:16] [main/WARN]: Error loading class: net/minecraft/class_436 (java.lang.ClassNotFoundException: net/minecraft/class_436)
# [17:51:16] [main/WARN]: @Mixin target net.minecraft.class_436 was not found luna.mixins.json:LANMixin from mod luna
# [17:51:16] [main/WARN]: Error loading class: net/minecraft/class_287 (java.lang.ClassNotFoundException: net/minecraft/class_287)
# [17:51:16] [main/WARN]: @Mixin target net.minecraft.class_287 was not found owo.mixins.json:BufferBuilderAccessor from mod owo
# [17:51:16] [main/WARN]: Error loading class: net/minecraft/class_437 (java.lang.ClassNotFoundException: net/minecraft/class_437)
# [17:51:16] [main/WARN]: @Mixin target net.minecraft.class_437 was not found owo.mixins.json:ScreenAccessor from mod owo
# [17:51:16] [main/WARN]: Error loading class: xyz/nucleoid/server/translations/impl/language/SystemDelegatedLanguage (java.lang.ClassNotFoundException: xyz/nucleoid/server/translations/impl/language/SystemDelegatedLanguage)
# [17:51:16] [main/WARN]: Error loading class: net/minecraft/class_638 (java.lang.ClassNotFoundException: net/minecraft/class_638)
# [17:51:16] [main/WARN]: @Mixin target net.minecraft.class_638 was not found porting_lib_level_events.mixins.json:client.ClientLevelMixin from mod porting_lib_level_events
# [17:51:16] [main/WARN]: Disabling fastItemComparison feature, due to the Owo mod's faulty implementation breaking it
# [17:51:16] [main/INFO]: Loaded config for: recipeessentials.json
# [17:51:16] [main/WARN]: Disabling fastItemComparison feature, due to the Owo mod's faulty implementation breaking it
# [17:51:16] [main/WARN]: Disabling fastItemComparison feature, due to the Owo mod's faulty implementation breaking it
# [17:51:16] [main/WARN]: Disabling fastItemComparison feature, due to the Owo mod's faulty implementation breaking it
# [17:51:16] [main/WARN]: Disabling fastItemComparison feature, due to the Owo mod's faulty implementation breaking it
# [17:51:16] [main/WARN]: Disabling fastItemComparison feature, due to the Owo mod's faulty implementation breaking it
# [17:51:16] [main/WARN]: Disabling fastItemComparison feature, due to the Owo mod's faulty implementation breaking it
# [17:51:17] [main/WARN]: Error loading class: com/nhoryzon/mc/farmersdelight/block/BuddingBushBlock (java.lang.ClassNotFoundException: com/nhoryzon/mc/farmersdelight/block/BuddingBushBlock)
# [17:51:17] [main/WARN]: @Mixin target com.nhoryzon.mc.farmersdelight.block.BuddingBushBlock was not found seasonsdelightcompat.mixins.json:BuddingBushBlockMixin from mod seasonsdelightcompat
# [17:51:17] [main/WARN]: Error loading class: com/nhoryzon/mc/farmersdelight/block/BuddingTomatoBlock (java.lang.ClassNotFoundException: com/nhoryzon/mc/farmersdelight/block/BuddingTomatoBlock)
# [17:51:17] [main/WARN]: @Mixin target com.nhoryzon.mc.farmersdelight.block.BuddingTomatoBlock was not found seasonsdelightcompat.mixins.json:BuddingTomatoBlockMixin from mod seasonsdelightcompat
# [17:51:17] [main/WARN]: Error loading class: com/nhoryzon/mc/farmersdelight/block/MushroomColonyBlock (java.lang.ClassNotFoundException: com/nhoryzon/mc/farmersdelight/block/MushroomColonyBlock)
# [17:51:17] [main/WARN]: @Mixin target com.nhoryzon.mc.farmersdelight.block.MushroomColonyBlock was not found seasonsdelightcompat.mixins.json:MushroomColonyBlockMixin from mod seasonsdelightcompat
# [17:51:17] [main/WARN]: Error loading class: com/nhoryzon/mc/farmersdelight/block/RiceCropBlock (java.lang.ClassNotFoundException: com/nhoryzon/mc/farmersdelight/block/RiceCropBlock)
# [17:51:17] [main/WARN]: @Mixin target com.nhoryzon.mc.farmersdelight.block.RiceCropBlock was not found seasonsdelightcompat.mixins.json:RiceCropBlockMixin from mod seasonsdelightcompat
# [17:51:17] [main/WARN]: Error loading class: com/nhoryzon/mc/farmersdelight/block/TomatoVineBlock (java.lang.ClassNotFoundException: com/nhoryzon/mc/farmersdelight/block/TomatoVineBlock)
# [17:51:17] [main/WARN]: @Mixin target com.nhoryzon.mc.farmersdelight.block.TomatoVineBlock was not found seasonsdelightcompat.mixins.json:TomatoVineBlockMixin from mod seasonsdelightcompat
# [17:51:17] [main/WARN]: Error loading class: sereneseasons/season/RandomUpdateHandler (java.lang.ClassNotFoundException: sereneseasons/season/RandomUpdateHandler)
# [17:51:17] [main/WARN]: @Mixin target sereneseasons.season.RandomUpdateHandler was not found snowrealmagic.mixins.json:sereneseasons.RandomUpdateHandlerMixin from mod snowrealmagic
# [17:51:17] [main/WARN]: Error loading class: net/caffeinemc/mods/sodium/client/render/frapi/render/AbstractBlockRenderContext (java.lang.ClassNotFoundException: net/caffeinemc/mods/sodium/client/render/frapi/render/AbstractBlockRenderContext)
# [17:51:17] [main/WARN]: @Mixin target net.caffeinemc.mods.sodium.client.render.frapi.render.AbstractBlockRenderContext was not found mixins.sodiumleafculling.json:AbstractBlockRenderContextAccessor from mod sodiumleafculling
# [17:51:17] [main/WARN]: Error loading class: net/caffeinemc/mods/sodium/client/render/chunk/compile/pipeline/BlockOcclusionCache (java.lang.ClassNotFoundException: net/caffeinemc/mods/sodium/client/render/chunk/compile/pipeline/BlockOcclusionCache)
# [17:51:17] [main/WARN]: @Mixin target net.caffeinemc.mods.sodium.client.render.chunk.compile.pipeline.BlockOcclusionCache was not found mixins.sodiumleafculling.json:BlockOcclusionCacheMixin from mod sodiumleafculling
# [17:51:17] [main/WARN]: Error loading class: net/caffeinemc/mods/sodium/client/render/chunk/compile/pipeline/BlockRenderer (java.lang.ClassNotFoundException: net/caffeinemc/mods/sodium/client/render/chunk/compile/pipeline/BlockRenderer)
# [17:51:17] [main/WARN]: @Mixin target net.caffeinemc.mods.sodium.client.render.chunk.compile.pipeline.BlockRenderer was not found mixins.sodiumleafculling.json:BlockRendererMixin from mod sodiumleafculling
# [17:51:17] [main/WARN]: Error loading class: net/caffeinemc/mods/sodium/client/gui/SodiumGameOptions$PerformanceSettings (java.lang.ClassNotFoundException: net/caffeinemc/mods/sodium/client/gui/SodiumGameOptions$PerformanceSettings)
# [17:51:17] [main/WARN]: @Mixin target net.caffeinemc.mods.sodium.client.gui.SodiumGameOptions$PerformanceSettings was not found mixins.sodiumleafculling.json:PerformanceSettingsMixin from mod sodiumleafculling
# [17:51:17] [main/WARN]: Error loading class: net/caffeinemc/mods/sodium/client/gui/SodiumGameOptionPages (java.lang.ClassNotFoundException: net/caffeinemc/mods/sodium/client/gui/SodiumGameOptionPages)
# [17:51:17] [main/WARN]: @Mixin target net.caffeinemc.mods.sodium.client.gui.SodiumGameOptionPages was not found mixins.sodiumleafculling.json:SodiumGameOptionPagesMixin from mod sodiumleafculling
# [17:51:17] [main/INFO]: Loaded config for: structureessentials.json
# [17:51:17] [main/WARN]: Error loading class: me/jellysquid/mods/sodium/client/render/chunk/compile/pipeline/FluidRenderer (java.lang.ClassNotFoundException: me/jellysquid/mods/sodium/client/render/chunk/compile/pipeline/FluidRenderer)
# [17:51:19] [main/WARN]: Error loading class: net/fabricmc/fabric/api/client/rendering/v1/EntityModelLayerRegistry$TexturedModelDataProvider (java.lang.ClassNotFoundException: net/fabricmc/fabric/api/client/rendering/v1/EntityModelLayerRegistry$TexturedModelDataProvider)
# [17:51:19] [main/WARN]: Error loading class: net/minecraft/class_314 (java.lang.ClassNotFoundException: net/minecraft/class_314)
# [17:51:19] [main/WARN]: @Mixin target net.minecraft.class_314 was not found mixins.mm.json:net.minecraft.class_314 from mod mm
# [17:51:19] [main/WARN]: Error loading class: net/minecraft/class_314 (java.lang.ClassNotFoundException: net/minecraft/class_314)
# [17:51:19] [main/WARN]: @Mixin target net.minecraft.class_314 was not found mixins.mm_shedaniel.json:net.minecraft.class_314 from mod mm_shedaniel
# [17:51:20] [main/WARN]: launchTarget: SERVER. Crash Assistant is client only mod. Mod will do nothing!
# [17:51:20] [main/INFO]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.5.0-beta.3).
# [17:51:22] [main/WARN]: @Inject(@At("INVOKE")) Shift.BY=2 on accessories-common.mixins.json:NbtCompoundMixin from mod accessories::handler$zgg000$accessories$adjustCheckForListVariants exceeds the maximum allowed value: 0. Increase the value of maxShiftBy to suppress this warning.
# [17:51:28] [main/INFO]: Injecting BlockStateBase cache population hook into getOpacityIfCached from ca.spottedleaf.starlight.mixin.common.blockstate.BlockStateBaseMixin
# [17:51:28] [main/INFO]: Injecting BlockStateBase cache population hook into isConditionallyFullOpaque from ca.spottedleaf.starlight.mixin.common.blockstate.BlockStateBaseMixin
# [17:51:30] [main/WARN]: @Redirect conflict. Skipping mixins.redirected_fabric_1.21.1.json:net.minecraft.world.level.block.RedStoneWireBlockMixin from mod redirected->@Redirect::redirectDirections()[Lnet/minecraft/class_2350; with priority 10, already redirected by lithium.mixins.json:alloc.enum_values.redstone_wire.RedStoneWireBlockMixin from mod lithium->@Redirect::removeAllocation1()[Lnet/minecraft/class_2350; with priority 1000
# [17:51:30] [main/WARN]: @Redirect conflict. Skipping mixins.redirected_fabric_1.21.1.json:net.minecraft.world.level.block.RedStoneWireBlockMixin from mod redirected->@Redirect::redirectDirections()[Lnet/minecraft/class_2350; with priority 10, already redirected by lithium.mixins.json:alloc.enum_values.redstone_wire.RedStoneWireBlockMixin from mod lithium->@Redirect::removeAllocation2()[Lnet/minecraft/class_2350; with priority 1000
# [17:51:31] [main/WARN]: @Redirect conflict. Skipping mixins.redirected_fabric_1.21.1.json:net.minecraft.world.level.block.piston.PistonBaseBlockMixin from mod redirected->@Redirect::redirectDirections()[Lnet/minecraft/class_2350; with priority 10, already redirected by lithium.mixins.json:alloc.enum_values.piston_block.PistonBaseBlockMixin from mod lithium->@Redirect::removeAllocation()[Lnet/minecraft/class_2350; with priority 1000
# [17:51:31] [main/WARN]: @Redirect conflict. Skipping mixins.redirected_fabric_1.21.1.json:net.minecraft.world.level.block.piston.PistonBaseBlockMixin from mod redirected->@Redirect::redirectDirections()[Lnet/minecraft/class_2350; with priority 10, already redirected by lithium.mixins.json:alloc.enum_values.piston_block.PistonBaseBlockMixin from mod lithium->@Redirect::removeAllocation()[Lnet/minecraft/class_2350; with priority 1000
# [17:51:35] [main/WARN]: Static binding violation: PRIVATE @Overwrite method method_21740 in modernfix-common.mixins.json:perf.remove_biome_temperature_cache.BiomeMixin from mod modernfix cannot reduce visibiliy of PUBLIC target method, visibility will be upgraded.
# [17:51:35] [main/WARN]: Method overwrite conflict for method_21740 in modernfix-common.mixins.json:perf.remove_biome_temperature_cache.BiomeMixin from mod modernfix, previously written by net.caffeinemc.mods.lithium.mixin.world.temperature_cache.BiomeMixin. Skipping method.
# [17:51:47] [main/INFO]: Vanilla bootstrap took 23828 milliseconds
# [17:51:51] [main/INFO]: Registered Trinkets Reloaded Listeners
# [17:51:51] [main/ERROR]: No data fixer registered for deeperdarker:angler_fish
# [17:51:51] [main/ERROR]: No data fixer registered for deeperdarker:sculk_centipede
# [17:51:51] [main/ERROR]: No data fixer registered for deeperdarker:sculk_leech
# [17:51:51] [main/ERROR]: No data fixer registered for deeperdarker:sculk_snapper
# [17:51:51] [main/ERROR]: No data fixer registered for deeperdarker:shattered
# [17:51:51] [main/ERROR]: No data fixer registered for deeperdarker:shriek_worm
# [17:51:51] [main/ERROR]: No data fixer registered for deeperdarker:sludge
# [17:51:51] [main/ERROR]: No data fixer registered for deeperdarker:stalker
# [17:51:52] [main/INFO]: Initializing platform helper for Advanced Netherite!
# [17:51:52] [main/INFO]: Adventure Dungeons Fabric Made by AlexMega
# [17:51:52] [main/INFO]: Hello from Common init on Fabric! we are currently in a production environment!
# [17:51:52] [main/INFO]: The ID for diamonds is minecraft:diamond
# [17:51:52] [main/INFO]: Hello to adventuredungeons
# [17:51:53] [main/INFO]: Processing wover.datapack.registry Entrypoints
# [17:51:53] [main/INFO]:     - Processing Entrypoint: org.betterx.wover.entrypoint.BiomeDatapackRegistryEntrypoint
# [17:51:53] [main/INFO]:     - Processing Entrypoint: org.betterx.wover.entrypoint.FeatureDatapackRegistryEntrypoint
# [17:51:53] [main/INFO]:     - Processing Entrypoint: org.betterx.wover.entrypoint.ItemDatapackRegistryEntrypoint
# [17:51:53] [main/INFO]:     - Processing Entrypoint: org.betterx.wover.entrypoint.StructureDatapackRegistryEntrypoint
# [17:51:53] [main/INFO]:     - Processing Entrypoint: org.betterx.wover.entrypoint.SurfaceDatapackRegistryEntrypoint
# [17:51:54] [main/INFO]: Loaded config amendments-common.json
# [17:51:54] [main/INFO]: [Animal Feeding Trough] Load Complete! Enjoy :D
# [17:51:54] [main/INFO]: Constructing common components for barteringstation:main
# [17:51:55] [main/INFO]: Better Compatibility Checker starting
# [17:51:55] [main/INFO]: Loading config file
# [17:51:55] [main/INFO]: Config file loaded
# [17:51:56] [main/INFO]: Reflections took 276 ms to scan 1 urls, producing 1 keys and 3 values
# [17:51:56] [main/INFO]: Reflections took 13 ms to scan 1 urls, producing 1 keys and 3 values
# [17:51:57] [main/INFO]: Applying Betterend Crashed Ship Tweaks
# [17:51:57] [main/INFO]: Reflections took 2 ms to scan 1 urls, producing 1 keys and 2 values
# [17:51:57] [main/INFO]: Reflections took 2 ms to scan 1 urls, producing 1 keys and 2 values
# [17:51:57] [main/INFO]: Reflections took 5 ms to scan 1 urls, producing 1 keys and 1 values
# [17:51:57] [main/INFO]: Reflections took 2 ms to scan 1 urls, producing 1 keys and 1 values
# [17:51:57] [main/INFO]: Reflections took 6 ms to scan 1 urls, producing 1 keys and 3 values
# [17:51:57] [main/INFO]: Reflections took 3 ms to scan 1 urls, producing 1 keys and 3 values
# [17:51:57] [main/INFO]: Reflections took 5 ms to scan 1 urls, producing 1 keys and 2 values
# [17:51:57] [main/INFO]: Reflections took 8 ms to scan 1 urls, producing 1 keys and 2 values
# [17:51:57] [main/INFO]: =^..^=    BetterNether for 1.21    =^..^=
# [17:51:57] [main/INFO]: Reflections took 5 ms to scan 1 urls, producing 1 keys and 1 values
# [17:51:57] [main/INFO]: Reflections took 3 ms to scan 1 urls, producing 1 keys and 1 values
# [17:51:57] [main/INFO]: Reflections took 9 ms to scan 1 urls, producing 1 keys and 2 values
# [17:51:57] [main/INFO]: Reflections took 6 ms to scan 1 urls, producing 1 keys and 2 values
# [17:51:57] [main/INFO]: Reflections took 1 ms to scan 1 urls, producing 1 keys and 1 values
# [17:51:57] [main/INFO]: Reflections took 2 ms to scan 1 urls, producing 1 keys and 1 values
# [17:51:58] [main/INFO]: biomemusic mod initialized
# [17:51:58] [main/INFO]: BoatBreakFix initialized
# [17:52:00] [main/INFO]: Loading 72 classes for charm
# [17:52:00] [main/ERROR]: No data fixer registered for charm:coral_squid
# [17:52:00] [main/ERROR]: No data fixer registered for charm:moobloom
# [17:52:00] [main/ERROR]: No data fixer registered for charm:chair
# [17:52:00] [main/ERROR]: No data fixer registered for charm:endermite_powder
# [17:52:01] [main/INFO]: Loaded config for: chunksending.json
# [17:52:01] [main/INFO]: chunksending mod initialized
# [17:52:01] [main/INFO]: Loading Collective version 7.91.
# [17:52:03] [main/INFO]: Connectivity initialized
# [17:52:03] [main/INFO]: fabric loader environment detected
# [17:52:03] [main/INFO]: Loaded config for: cupboard.json
# [17:52:03] [main/INFO]: Enabled 28 bug fixes: [MC-2025, MC-7569, MC-8187, MC-30391, MC-69216, MC-88371, MC-89146, MC-93018, MC-100991, MC-119417, MC-119754, MC-121706, MC-121903, MC-129909, MC-132878, MC-135971, MC-155509, MC-160095, MC-179072, MC-183990, MC-199467, MC-200418, MC-206922, MC-215530, MC-223153, MC-224729, MC-231743, MC-232869]
# [17:52:03] [main/INFO]: Successfully Debugify'd your game!
# [17:52:03] [main/ERROR]: No data fixer registered for crystallized_amber
# [17:52:03] [main/ERROR]: No data fixer registered for sculk_jaw
# [17:52:04] [main/INFO]: Loaded DEUF Refabricated Config
# [17:52:04] [main/INFO]: Constructing common components for diagonalblocks:main
# [17:52:04] [main/INFO]: Constructing common components for diagonalfences:main
# ...
#          preset     = none
#          noise      = the_bumblezone:bz_noise_settings
#          features   = the_bumblezone(119)
#      BzBiomeSource (3c72397)
#          biomes     = 8
#          namespaces = the_bumblezone(8)
#  - minecraft:the_nether:
#      WoVer - Chunk Generator (5f50c658)
#          preset     = wover:normal
#          noise      = minecraft:nether
#          features   = minecraft(539), repurposed_structures(64), betternether(333), biomesoplenty(27), supplementaries(1), mynethersdelight(1), hearths(14)
#      WoVer - Nether BiomeSource (7acf111a)
#          biomes     = 32
#          namespaces = betternether(22), minecraft(5), biomesoplenty(5)
#          seed       = -3923420895776043876
#          height     = 128
#          config     = NetherConfig{mapVersion=hex, useVerticalBiomes=true, biomeSize=16, biomeSizeVertical=5}
#  - paradise_lost:paradise_lost:
#      class_3754 (1ff5a30d)
#          preset     = none
#          noise      = paradise_lost:noise
#          features   = minecraft(8), paradise_lost(155)
#      class_4766 (18f2955c)
#          biomes     = 8
#          namespaces = paradise_lost(8)
#  - minecraft:the_end:
#      WoVer - Chunk Generator (357312da)
#          preset     = wover:normal
#          noise      = minecraft:end
#          features   = minecraft(27), repurposed_structures(27), biomesoplenty(17), betterend(271)
#      WoVer - The End  BiomeSource (d75e703)
#          biomes     = 27
#          namespaces = minecraft(5), betterend(19), biomesoplenty(3)
#          seed       = -3923420895776043876
#          height     = 128
#          deciders   = 0
#          config     = EndConfig{mapVersion=hex, generatorVersion=vanilla, withVoidBiomes=true, innerVoidRadius=1024, voidBiomesSize=16, centerBiomesSize=16, landBiomesSize=16, barrensBiomesSize=16}
#  - deeperdarker:otherside:
#      class_3754 (35744302)
#          preset     = none
#          noise      = deeperdarker:otherside
#          features   = minecraft(6), deeperdarker(66)
#      class_4766 (43a73cd7)
#          biomes     = 4
#          namespaces = deeperdarker(4)
#  - uf_data:data:
#      class_2897 (3307d811)
#          preset     = none
#          features   = none
#      class_1992 (243e1466)
#          biomes     = 1
#          namespaces = minecraft(1)
# [17:53:40] [Server thread/INFO]: Merged 22 additional Surface Rules for Dimension minecraft:the_nether => 74 (2.946 ms) using WoVer - Nether BiomeSource (7acf111a)
#     biomes     = 32
#     namespaces = betternether(22), minecraft(5), biomesoplenty(5)
#     seed       = -3923420895776043876
#     height     = 128
#     config     = NetherConfig{mapVersion=hex, useVerticalBiomes=true, biomeSize=16, biomeSizeVertical=5}
# [17:53:40] [Server thread/INFO]: Merged 19 additional Surface Rules for Dimension minecraft:the_end => 20 (939.3 μs) using WoVer - The End  BiomeSource (d75e703)
#     biomes     = 27
#     namespaces = minecraft(5), betterend(19), biomesoplenty(3)
#     seed       = -3923420895776043876
#     height     = 128
#     deciders   = 0
#     config     = EndConfig{mapVersion=hex, generatorVersion=vanilla, withVoidBiomes=true, innerVoidRadius=1024, voidBiomesSize=16, centerBiomesSize=16, landBiomesSize=16, barrensBiomesSize=16}
# [17:53:42] [Server thread/INFO]: Added 2 Biomes
# [17:53:42] [Server thread/INFO]:  - minecraft:end_barrens, subbiomes=1
# [17:53:42] [Server thread/INFO]:  - minecraft:end_midlands, subbiomes=1
# [17:53:42] [Server thread/INFO]: Added 2 Biomes
# [17:53:42] [Server thread/INFO]:  - minecraft:end_barrens, subbiomes=1
# [17:53:42] [Server thread/INFO]:  - minecraft:end_midlands, subbiomes=1
# [17:53:43] [Server thread/INFO]: Added 2 Biomes
# [17:53:43] [Server thread/INFO]:  - minecraft:end_barrens, subbiomes=1
# [17:53:43] [Server thread/INFO]:  - minecraft:end_midlands, subbiomes=1
# [17:53:43] [Server thread/INFO]: Added 2 Biomes
# [17:53:43] [Server thread/INFO]:  - minecraft:end_barrens, subbiomes=1
# [17:53:43] [Server thread/INFO]:  - minecraft:end_midlands, subbiomes=1
# [17:53:43] [Server thread/INFO]: Added 2 Biomes
# [17:53:43] [Server thread/INFO]:  - minecraft:end_barrens, subbiomes=1
# [17:53:43] [Server thread/INFO]:  - minecraft:end_midlands, subbiomes=1
# [17:53:45] [Server thread/INFO]: Added 2 Biomes
# [17:53:45] [Server thread/INFO]:  - minecraft:end_barrens, subbiomes=1
# [17:53:45] [Server thread/INFO]:  - minecraft:end_midlands, subbiomes=1
# [17:53:45] [Server thread/INFO]: Added 2 Biomes
# [17:53:45] [Server thread/INFO]:  - minecraft:end_barrens, subbiomes=1
# [17:53:45] [Server thread/INFO]:  - minecraft:end_midlands, subbiomes=1
# [17:53:45] [Server thread/INFO]: Added 2 Biomes
# [17:53:45] [Server thread/INFO]:  - minecraft:end_barrens, subbiomes=1
# [17:53:45] [Server thread/INFO]:  - minecraft:end_midlands, subbiomes=1
# [17:53:45] [Server thread/INFO]: Added 2 Biomes
# [17:53:45] [Server thread/INFO]:  - minecraft:end_barrens, subbiomes=1
# [17:53:45] [Server thread/INFO]:  - minecraft:end_midlands, subbiomes=1
# [17:53:45] [Server thread/INFO]: Preparing start region for dimension minecraft:overworld
# [17:53:45] [Server thread/WARN]: Method overwrite conflict for removeIf in modernfix-common.mixins.json:bugfix.paper_chunk_patches.SortedArraySetMixin from mod modernfix, previously written by net.caffeinemc.mods.lithium.mixin.collections.chunk_tickets.SortedArraySetMixin. Skipping method.
# [17:53:46] [Server thread/INFO]: [STDOUT]: [ScalableLux] Lighting scaling is disabled (due to low parallelism in the settings)
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:57] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:58] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [17:53:59] [Server thread/INFO]: Time elapsed: 13641 ms
# [17:53:59] [Server thread/INFO]: Done (21.246s)! For help, type "help"
# [17:53:59] [Server thread/WARN]: Dedicated server took 182.63 seconds to load
# [17:53:59] [Server thread/INFO]: Loading quests from /content/drive/My Drive/Minecraft-server_Better_MC/config/ftbquests/quests
# [17:53:59] [Server thread/INFO]: loaded translation tables for 1 language(s)
# [17:53:59] [Server thread/INFO]: Loaded 3 chapter groups, 9 chapters, 79 quests, 0 reward tables
# [17:53:59] [Server thread/INFO]: Loaded config for: connectivity.json
# [17:53:59] [Server thread/INFO]: Loaded config for: lootintegrations.json
# [17:53:59] [Server thread/INFO]: Loaded config for: smoothchunk.json
# [17:53:59] [Server thread/INFO]: Loaded config for: biomemusic.json
# [17:54:00] [Server thread/INFO]: Start loading plugin from Jade: snownee.jade.addon.core.CorePlugin
# [17:54:00] [Server thread/INFO]: Start loading plugin from Jade: snownee.jade.addon.vanilla.VanillaPlugin
# [17:54:00] [Server thread/INFO]: Start loading plugin from Jade: snownee.jade.addon.universal.UniversalPlugin
# [17:54:00] [Server thread/INFO]: Start loading plugin from Jade: snownee.jade.addon.access.AccessibilityPlugin
# [17:54:00] [Server thread/INFO]: Start loading plugin from Jade: snownee.jade.addon.debug.DebugPlugin
# [17:54:00] [Server thread/INFO]: Start loading plugin from Your Reputation: atonkish.reputation.ReputationPlugin
# [17:54:00] [Server thread/INFO]: Start loading plugin from Snow! Real Magic!: snownee.snow.compat.jade.JadeCompat
# [17:54:00] [Server thread/INFO]: Start loading plugin from Supplementaries: net.mehvahdjukaar.supplementaries.integration.JadeCompat
# [17:54:00] [Server thread/INFO]: Start loading plugin from Tom's Simple Storage Mod: com.tom.storagemod.jade.JadePlugin
# [17:54:01] [Server thread/INFO]: Added 2 Biomes
# [17:54:01] [Server thread/INFO]:  - minecraft:end_barrens, subbiomes=1
# [17:54:01] [Server thread/INFO]:  - minecraft:end_midlands, subbiomes=1
# [17:54:23] [Server thread/INFO]: Added 2 Biomes
# [17:54:23] [Server thread/INFO]:  - minecraft:end_barrens, subbiomes=1
# [17:54:23] [Server thread/INFO]:  - minecraft:end_midlands, subbiomes=1
# [17:54:23] [Server thread/INFO]: Loading claims...
# [17:54:23] [Server thread/INFO]: Loaded claims in 18ms
# [17:54:23] [Server thread/WARN]: The configured permission system "prometheus" isn't registered!
# [17:54:23] [Server thread/INFO]: Configured OPAC to use the following permission system: permission_api
# [17:54:23] [Server thread/WARN]: The configured primary party system "argonauts_guilds" isn't registered!
# [17:54:23] [Server thread/INFO]: Configured OPAC to use the following party system as primary: default
# [17:54:23] [Server thread/INFO]: Registered synced player tracker system: ftb_teams
# [17:54:24] [Server thread/INFO]: Registered synced player tracker system: ftb_teams
# [17:54:24] [Server thread/INFO]: Auto report config loaded for mod: "the_bumblezone"
# [17:54:24] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 24558ms or 491 ticks behind
# [17:54:24] [Server thread/INFO]: Loading Xaero's Minimap - Stage 2/2 (Server)
# [17:54:24] [Server thread/INFO]: Loading Xaero's World Map - Stage 2/2 (Server)
# [17:54:24] [Server thread/INFO]: Loading data for 12 chunks for filePath './world/chunk_activity_info/overworld.dat' took 35 milliseconds
# [17:54:24] [Server thread/INFO]: Saving data for 12 chunks for dimension 'overworld' took 28 milliseconds
# [17:54:54] [Netty Epoll Server IO #3/WARN]: @ModifyConstant conflict. Skipping connectivity.mixins.json:ClientboundCustomPayloadPacketMixin from mod connectivity->@ModifyConstant::modifyLimit(I)I with priority 1, already redirected by packetfixer.common.mixins.json:ClientboundCustomPayloadPacketMixin from mod packetfixer->@ModifyConstant::newSize$1(I)I with priority 1000
# [17:54:54] [Netty Epoll Server IO #3/WARN]: @ModifyConstant conflict. Skipping connectivity.mixins.json:ClientboundCustomPayloadPacketMixin from mod connectivity->@ModifyConstant::modifyLimit2(I)I with priority 1, already redirected by packetfixer.common.mixins.json:ClientboundCustomPayloadPacketMixin from mod packetfixer->@ModifyConstant::newSize$2(I)I with priority 1000
# [17:55:04] [Server thread/INFO]: [STDOUT]: Lithium Cached BlockState Flags are disabled!
# [17:55:04] [Server thread/INFO]: black_shadow3127[/127.0.0.1:43970] logged in with entity id 110 at (105.69999998807907, 63.0, 23.695548273380258)
# [17:55:04] [Server thread/INFO]: Sending server config values to client
# [17:55:06] [Server thread/INFO]: black_shadow3127 joined the game
# [17:55:07] [Server thread/INFO]: Updating all forceload tickets for e050b92d-e110-362a-b1a6-a2ed410692da
# [17:55:07] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 3299ms or 65 ticks behind
# [17:55:08] [Server thread/WARN]: @ModifyConstant conflict. Skipping packetfixer.common.mixins.json:ClientboundLevelChunkPacketDataMixin from mod packetfixer->@ModifyConstant::init$size(I)I with priority 1000, already redirected by connectivity.mixins.json:ClientBoundLevelChunkPacketDataLimitMixin from mod connectivity->@ModifyConstant::modifyLimit(I)I with priority 1000
# [17:55:08] [Server thread/INFO]: Channel update: black_shadow3127 -> default
# [17:55:08] [Server thread/INFO]: Priority overwritten for player black_shadow3127. Claiming: GRAVE / Robbing: INVENTORY
# [17:55:08] [Server thread/INFO]: Receiving client config
# [17:55:30] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 8586ms or 171 ticks behind
# [17:55:50] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 4258ms or 85 ticks behind
# /op black_shadow3127
# [17:56:09] [Server thread/INFO]: Made black_shadow3127 a server operator
# [17:56:10] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 4962ms or 99 ticks behind
# [17:56:31] [Server thread/INFO]: [black_shadow3127: Set own game mode to Creative Mode]
# [17:56:32] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 2009ms or 40 ticks behind
# [17:57:00] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 2030ms or 40 ticks behind
# [17:57:03] [Server thread/INFO]: [black_shadow3127: Set own game mode to Spectator Mode]
# [17:57:20] [Server thread/INFO]: black_shadow3127 has made the advancement [A Warm and Beautiful Light]
# [17:57:22] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 7397ms or 147 ticks behind
# [17:57:29] [Worker-Main-1/WARN]: Empty height range: [30 absolute-20 absolute]
# [17:59:56] [Server thread/INFO]: Saving data for 104 chunks for dimension 'overworld' took 52 milliseconds
# [18:00:28] [Server thread/INFO]: [black_shadow3127: Teleported black_shadow3127 to 0.500000, 0.000000, 0.500000]
# [18:01:51] [Server thread/INFO]: Villager class_1646['Uchtrid Aldis'/31, l='ServerLevel[world]', x=57.30, y=60.89, z=6.70] died, message: 'Uchtrid Aldis was slain by Zombie'
# [18:01:51] [Server thread/INFO]: Named entity class_1646['Uchtrid Aldis'/31, l='ServerLevel[world]', x=57.30, y=60.89, z=6.70] died: Uchtrid Aldis was slain by Zombie
# [18:02:09] [Server thread/INFO]: Villager class_1646['Fabion Paeth'/104, l='ServerLevel[world]', x=46.33, y=67.00, z=2.65] died, message: 'Fabion Paeth was slain by Zombie'
# [18:02:09] [Server thread/INFO]: Named entity class_1646['Fabion Paeth'/104, l='ServerLevel[world]', x=46.33, y=67.00, z=2.65] died: Fabion Paeth was slain by Zombie
# [18:04:55] [Server thread/INFO]: Named entity class_1641['Fabion Paeth the Zombie'/2060, l='ServerLevel[world]', x=10.00, y=72.00, z=17.68] died: Fabion Paeth the Zombie burned to death
# [18:04:56] [Server thread/INFO]: Saving data for 118 chunks for dimension 'overworld' took 35 milliseconds
# [18:05:05] [Server thread/INFO]: Named entity class_1641['Uchtrid Aldis the Zombie'/2059, l='ServerLevel[world]', x=5.55, y=71.00, z=32.29] died: Uchtrid Aldis the Zombie burned to death
# [18:06:13] [Worker-Main-4/WARN]: Ignoring unknown attribute 'porting_lib:step_height_addition'
# [18:06:13] [Worker-Main-4/WARN]: Ignoring unknown attribute 'porting_lib:entity_gravity'
# [18:06:13] [Worker-Main-4/WARN]: Ignoring unknown attribute 'porting_lib:step_height_addition'
# [18:06:13] [Worker-Main-4/WARN]: Ignoring unknown attribute 'porting_lib:entity_gravity'
# [18:06:20] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 4543ms or 90 ticks behind
# [18:10:01] [Server thread/INFO]: Saving data for 141 chunks for dimension 'overworld' took 38 milliseconds
# [18:11:27] [Server thread/INFO]: [black_shadow3127: Teleported black_shadow3127 to 0.500000, 0.000000, 0.500000]
# [18:12:13] [Server thread/INFO]: [black_shadow3127: Set own game mode to Survival Mode]
# [18:13:28] [Server thread/INFO]: Villager class_1646['Hulð Barrios'/78, l='ServerLevel[world]', x=-28.05, y=75.00, z=-13.89] died, message: 'Hulð Barrios was slain by Zombie'
# [18:13:28] [Server thread/INFO]: Named entity class_1646['Hulð Barrios'/78, l='ServerLevel[world]', x=-28.05, y=75.00, z=-13.89] died: Hulð Barrios was slain by Zombie
# [18:15:01] [Server thread/INFO]: Saving data for 160 chunks for dimension 'overworld' took 19 milliseconds
# ^C
# ✅ Minecraft server closed!
