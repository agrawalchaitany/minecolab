# %% [markdown]
# # 🎮 **Create a Minecraft Server on Google Colab!**
# 🚀 Set up and run your own **Minecraft server** effortlessly!
#
# ---
#
# ## 📌 **How It Works:**
# ✔️ **The script below will initiate your server.**
# ✔️ **First, you'll need to create the server** before running it.
# ✔️ **No worries!** The scripts below will handle most of the setup for you.
#
# 💡 **Want to change the server's region?** Check the instructions below.
#
# ---
#
# ## 🔗 **Original Repository:**
# [GitHub - agrawalchaitany/minecolab](https://github.com/agrawalchaitany/minecolab.git)
#
# ## ⚡ **Modified Version:**
# ✅ **Well-Optimized for Performance**
#
# ---
#
#
#
# ```
# ███╗   ███╗██╗███╗   ██╗███████╗ ██████╗ ██████╗ ██╗      █████╗ ██████╗
# ████╗ ████║██║████╗  ██║██╔════╝██╔════╝██╔═══██╗██║     ██╔══██╗██╔══██╗
# ██╔████╔██║██║██╔██╗ ██║█████╗  ██║     ██║   ██║██║     ███████║██████╔╝
# ██║╚██╔╝██║██║██║╚██╗██║██╔══╝  ██║     ██║   ██║██║     ██╔══██║██╔══██╗
# ██║ ╚═╝ ██║██║██║ ╚████║███████╗╚██████╗╚██████╔╝███████╗██║  ██║██████╔╝
# ╚═╝     ╚═╝╚═╝╚═╝  ╚═══╝╚══════╝ ╚═════╝ ╚═════╝ ╚══════╝╚═╝  ╚═╝╚═════╝
#
# ```
#
# 🎉 **Enjoy your Minecraft server on Google Colab!**

# %% [markdown]
# # 🛠️ **Step 1: Create the Server (First-Time Setup Only)**
# 🚀 **Run this step only once** to set up your server and accept the EULA.
#
# ---
#
# ## 📌 **What This Does:**
# ✔️ Creates your **Minecraft server**
# ✔️ Automatically **accepts the EULA**
# ✔️ Prepares the server for **quick startup**
#
# ---
#
# 🎮 **After this, your server will be ready to launch!** 🚀

# %% [markdown]
# # ⬇️ **Download the Cobblemon Server**
# 🚀 A **high-performance Fabric server** for an enhanced gaming experience!
#
# ---
#
# ## 📌 **About**
# The code below will **download** the **Cobblemon** server.
#
# 📂 **Storage Location:**
# The server files will be **saved on your Google Drive**
# (Linked to the Google account you choose or are currently using).
#
# ---
#
# ✅ **Enjoy seamless performance with Fabric!**

# %%
# ╔════════════════════════════════════════════════════╗
# ║         🎮 Cobblemon Official Modpack [Fabric] 1.6.1         ║
# ╚════════════════════════════════════════════════════╝

# 🔹 By:            CobbledStudios
# 📅 Release Date:  January 28, 2025
# 📂 File Size:     89.91 MB
# 📥 Downloads:     229.0K
# 🎮 Minecraft Ver: 1.21.1
# 🛠 Mod Loader:    Fabric

# ──────────────────────────────────────────────
# 📁 FILE INFORMATION
# ──────────────────────────────────────────────
# 📝 File Name:      Cobblemon Modpack [Fabric] 1.6.1.zip
# ✅ Supported Ver:   1.21.1
# ──────────────────────────────────────────────




import requests
import json
import os
import shutil
from google.colab import drive

# Mount Google Drive
drive.mount("/content/drive")

# Configuration
MINECRAFT_VERSION = "1.21.1"
SERVER_TYPE = "Cobblemon"
SERVER_DIR = "/content/drive/My Drive/Minecraft-server_Cobblemon"
os.makedirs(SERVER_DIR, exist_ok=True)


# download URLs
server_urls = {
    "Cobblemon": "https://www.curseforge.com/api/v1/mods/821748/files/6132445/download",
}
file_name ={
    "Cobblemon": "Cobblemon.zip",
}

download_url = server_urls.get(SERVER_TYPE)
zip_file="/content/drive/My Drive/Minecraft-server_Cobblemon/Cobblemon.zip"
# Download the selected server
if download_url:
    print(f"Downloading {SERVER_TYPE} server from {download_url}...")
    response = requests.get(download_url)

    if response.status_code == 200:
        with open(os.path.join(SERVER_DIR, file_name[SERVER_TYPE]), "wb") as f:
          f.write(response.content)
        shutil.unpack_archive(zip_file, SERVER_DIR)
        print("unzip successfully.")
        print(f"{SERVER_TYPE} server downloaded successfully.")
    else:
        print(f"Failed to download {SERVER_TYPE} server. Status code: {response.status_code}")
else:
    print(f"Invalid server type or missing URL: {SERVER_TYPE}")

os.system("bash start.sh")

# Save configuration
config_data = {"server_type": SERVER_TYPE, "server_version": MINECRAFT_VERSION }
with open(os.path.join(SERVER_DIR, "colabconfig.json"), "w") as config_file:
    json.dump(config_data, config_file)

print("Setup complete!")

# Accept Minecraft EULA
eula_path = os.path.join(SERVER_DIR, "eula.txt")
with open(eula_path, "w") as eula_file:
    eula_file.write("eula=true\n")

print("EULA accepted. Ready to start the server!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading Cobblemon server from https://www.curseforge.com/api/v1/mods/821748/files/6132445/download...
# unzip successfully.
# Cobblemon server downloaded successfully.
# Setup complete!
# EULA accepted. Ready to start the server!

# %% [markdown]
# ### 🚀 Starting the Minecraft Server
# 💡 Use this whenever you want to open the server.
#
# ---
#
# ## 🎮 Minecraft Server Configuration
#
# ### 🔧 Edit `server.properties` to Customize Settings:
# ```properties
# difficulty=hard
# max-players=10
# online-mode=false # For cracked servers(For example - Tlauncher)
# server-port=25565 # ⚠️ Must be set
# ```
#
# ---
#
# ### 🔗 Important Note:
#   ⚠️ Must change **key binds** after entering the game

# %%
import os
import time
import json
import re
from google.colab import drive

# 🛠️ Update package lists
print("\n🔄 Updating package lists...")
os.system("sudo apt update &>/dev/null && echo '✅ apt cache successfully updated' || echo '❌ apt cache update failed.'")

# 📂 Mount Google Drive
print("\n🔗 Mounting Google Drive...")
drive.mount('/content/drive')

# 🎮 Change directory to Minecraft server folder
server_path = "/content/drive/My Drive/Minecraft-server_Cobblemon"
if os.path.exists(server_path):
    os.chdir(server_path)
    print(f"✅ Changed working directory to: {server_path}")
    print("📂 Listing server files:\n")
    # !ls
else:
    print(f"❌ Error: {server_path} not found. Make sure the folder exists in Google Drive.")
    exit()

# 🔧 Load or create configuration file
config_file = "colabconfig.json"
if os.path.isfile(config_file):
    with open(config_file, "r") as f:
        colabconfig = json.load(f)
else:
    colabconfig = {"server_type": "generic"}
    with open(config_file, "w") as f:
        json.dump(colabconfig, f)

server_type = colabconfig.get("server_type", "generic")

# ☕ Install OpenJDK 21
print("\n🔧 Installing OpenJDK 21...")
os.system("sudo apt-get install openjdk-21-jre-headless -y &>/dev/null")

# ✅ Verify Java installation
java_version = os.popen("java -version 2>&1 | awk -F '\"' 'NR==1 {print $2}'").read().strip()
if java_version.startswith("21"):
    print(f"✅ OpenJDK {java_version} is working correctly.")
else:
    print(f"⚠️ OpenJDK 21 is not installed or not working. Detected Java version: {java_version}")
    exit()


# 🗂️ Server jar names
jar_list = {
    'Cobblemon': 'fabric-server-mc.1.21.1-loader.0.16.10-launcher.1.0.1.jar',
}
jar_name = jar_list.get(server_type, "fabric-server-mc.1.21.1-loader.0.16.10-launcher.1.0.1.jar")


# 🔧 Java arguments for better performance
if server_type in ["Cobblemon"]:
    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"
else:
    server_flags = ""

memory_allocation = "-Xms8704M -Xmx8704M"


# 🌍 tunneling service availble
#  -nglocalhost
#  -pinggy

# 🌍 Setup tunneling service
tunnel_service = "pinggy"  # Can be changed to "pinggy" if needed
print(f"\n🌍 Using {tunnel_service} for server tunneling...")
key_path = "/content/drive/My Drive/Minecraft-server_Cobblemon/ssh_keys/id_rsa"

# ⏳ Generate SSH key if missing.
def generate_ssh_key(key_path):

    if not os.path.isfile(key_path):
        os.makedirs(os.path.dirname(key_path), exist_ok=True)
        os.system(f"ssh-keygen -t rsa -b 4096 -f '{key_path}' -N '' -q")
        os.system(f"chmod 400 '{key_path}'")
        os.system(f"ssh-keygen -lf '{key_path}.pub' > '{key_path}_fingerprint.txt'")

print(f"\n🔌 Setting up {tunnel_service} tunneling...")

# 🔌 Establishing the tunnel
if tunnel_service == "nglocalhost":

    # ⏳ Generate SSH key if missing
    generate_ssh_key(key_path)

    # Establish tunnel
    print("⏳ Establishing tunnel, please wait...")
    os.system("nohup ssh -T -o StrictHostKeyChecking=no -i '/content/drive/My Drive/Minecraft-server_Cobblemon/ssh_keys/id_rsa' -R minecraft03127:25565:localhost:25565 nglocalhost.com > tunnel_log.txt 2>&1 &")
    url_pattern=r"(nglocalhost:[^\s]+)"
    # Wait for tunnel to establish
    time.sleep(10)

elif tunnel_service == "pinggy":

    # ⏳ Generate SSH key if missing
    generate_ssh_key(key_path)

    # Establish tunnel
    print("⏳ Establishing tunnel, please wait...")
    os.system("nohup ssh -p 443 -o StrictHostKeyChecking=no -o ServerAliveInterval=30 -R0:127.0.0.1:25565 tcp@ap.a.pinggy.io > tunnel_log.txt 2>&1 &")
    url_pattern=r"(tcp://[^\s]+)"
    # Wait for tunnel to establish
    time.sleep(10)

else:
    print("⚠️ No tunneling service selected. Server will run locally.")

# Extract and display the tunnel URL
with open("tunnel_log.txt", "r") as log_file:
    log_content = log_file.read()
    match = re.search(url_pattern, log_content)  # Extract first URL
    if match:
        tunnel_url = match.group(0)
        print(f"✅ Tunnel established! Access your Minecraft server at:\n🌍 {tunnel_url}")
    else:
        print("⚠️ Could not extract tunnel URL. Check 'tunnel_log.txt' manually.")

# 🚀 Start Minecraft server
print("\n🚀 Starting Minecraft server...")
# !java {memory_allocation} {server_flags} -jar {jar_name} nogui
print("✅ Minecraft server closed!")
# Out:
# 🔄 Updating package lists...
#
# 🔗 Mounting Google Drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Changed working directory to: /content/drive/My Drive/Minecraft-server_Cobblemon
# 📂 Listing server files:
#
# banned-ips.json						   logs		      start.sh
# banned-players.json					   mods		      tunnel_log.txt
# Cobblemon.zip						   ops.json	      usercache.json
# colabconfig.json					   server-icon.png    versions
# config							   server.properties  whitelist.json
# eula.txt						   showdown	      world
# fabric-server-mc.1.21.1-loader.0.16.10-launcher.1.0.1.jar  ssh_keys
# libraries						   start.bat
#
# 🔧 Installing OpenJDK 21...
# ✅ OpenJDK 21.0.6 is working correctly.
#
# 🌍 Using pinggy for server tunneling...
#
# 🔌 Setting up pinggy tunneling...
# ⏳ Establishing tunnel, please wait...
# ✅ Tunnel established! Access your Minecraft server at:
# 🌍 tcp://rnozv-34-148-62-206.a.free.pinggy.link:42109
#
# 🚀 Starting Minecraft server...
# Starting net.fabricmc.loader.impl.game.minecraft.BundlerClassPathCapture
# [15:01:58] [main/INFO]: Loading Minecraft 1.21.1 with Fabric Loader 0.16.10
# [15:01:59] [main/INFO]: Loading 75 mods:
# 	- almanac 1.0.2
# 	- appleskin 3.0.6+mc1.21
# 	   \-- cloth-config 15.0.127
# 	        \-- cloth-basic-math 0.6.1
# 	- architectury 13.0.8
# 	- cicada 0.10.2+1.21-1.21.1
# 	- clumps 19.0.0.1
# 	- cobblemon 1.6.1+1.21.1
# 	   \-- fabric-language-kotlin 1.11.0+kotlin.2.0.0
# 	        |-- org_jetbrains_kotlin_kotlin-reflect 2.0.0
# 	        |-- org_jetbrains_kotlin_kotlin-stdlib 2.0.0
# 	        |-- org_jetbrains_kotlin_kotlin-stdlib-jdk7 2.0.0
# 	        |-- org_jetbrains_kotlin_kotlin-stdlib-jdk8 2.0.0
# 	        |-- org_jetbrains_kotlinx_atomicfu-jvm 0.24.0
# 	        |-- org_jetbrains_kotlinx_kotlinx-coroutines-core-jvm 1.8.1
# 	        |-- org_jetbrains_kotlinx_kotlinx-coroutines-jdk8 1.8.1
# 	        |-- org_jetbrains_kotlinx_kotlinx-datetime-jvm 0.6.0
# 	        |-- org_jetbrains_kotlinx_kotlinx-serialization-cbor-jvm 1.6.3
# 	        |-- org_jetbrains_kotlinx_kotlinx-serialization-core-jvm 1.6.3
# 	        \-- org_jetbrains_kotlinx_kotlinx-serialization-json-jvm 1.6.3
# 	- collective 7.87
# 	- dismountentity 3.5
# 	- fabric-api 0.115.0+1.21.1
# 	   |-- fabric-api-base 0.4.42+6573ed8c19
# 	   |-- fabric-api-lookup-api-v1 1.6.70+b559734419
# 	   |-- fabric-biome-api-v1 13.0.31+d527f9fd19
# 	   |-- fabric-block-api-v1 1.0.22+0af3f5a719
# 	   |-- fabric-block-view-api-v2 1.0.10+6573ed8c19
# 	   |-- fabric-blockrenderlayer-v1 1.1.52+0af3f5a719
# 	   |-- fabric-client-tags-api-v1 1.1.15+6573ed8c19
# 	   |-- fabric-command-api-v1 1.2.49+f71b366f19
# 	   |-- fabric-command-api-v2 2.2.28+6ced4dd919
# 	   |-- fabric-commands-v0 0.2.66+df3654b319
# 	   |-- fabric-content-registries-v0 8.0.18+b559734419
# 	   |-- fabric-convention-tags-v1 2.1.2+7f945d5b19
# 	   |-- fabric-convention-tags-v2 2.9.2+e60e56d419
# 	   |-- fabric-crash-report-info-v1 0.2.29+0af3f5a719
# 	   |-- fabric-data-attachment-api-v1 1.4.1+9ed317f519
# 	   |-- fabric-data-generation-api-v1 20.2.25+16c4ae2519
# 	   |-- fabric-dimensions-v1 4.0.0+6fc22b9919
# 	   |-- fabric-entity-events-v1 1.7.0+2122d82819
# 	   |-- fabric-events-interaction-v0 0.7.13+ba9dae0619
# 	   |-- fabric-game-rule-api-v1 1.0.53+6ced4dd919
# 	   |-- fabric-item-api-v1 11.1.1+d5debaed19
# 	   |-- fabric-item-group-api-v1 4.1.6+6823f7cd19
# 	   |-- fabric-key-binding-api-v1 1.0.47+0af3f5a719
# 	   |-- fabric-keybindings-v0 0.2.45+df3654b319
# 	   |-- fabric-lifecycle-events-v1 2.5.0+01d9a51c19
# 	   |-- fabric-loot-api-v2 3.0.15+3f89f5a519
# 	   |-- fabric-loot-api-v3 1.0.3+3f89f5a519
# 	   |-- fabric-message-api-v1 6.0.13+6573ed8c19
# 	   |-- fabric-model-loading-api-v1 2.0.0+fe474d6b19
# 	   |-- fabric-networking-api-v1 4.3.0+c7469b2119
# 	   |-- fabric-object-builder-api-v1 15.2.1+40875a9319
# 	   |-- fabric-particles-v1 4.0.2+6573ed8c19
# 	   |-- fabric-recipe-api-v1 5.0.14+248df81c19
# 	   |-- fabric-registry-sync-v0 5.2.0+34f5d91419
# 	   |-- fabric-renderer-api-v1 3.4.0+c705a49c19
# 	   |-- fabric-renderer-indigo 1.7.0+c705a49c19
# 	   |-- fabric-renderer-registries-v1 3.2.68+df3654b319
# 	   |-- fabric-rendering-data-attachment-v1 0.3.48+73761d2e19
# 	   |-- fabric-rendering-fluids-v1 3.1.6+1daea21519
# 	   |-- fabric-rendering-v0 1.1.71+df3654b319
# 	   |-- fabric-rendering-v1 5.0.5+df16efd019
# 	   |-- fabric-resource-conditions-api-v1 4.3.0+8dc279b119
# 	   |-- fabric-resource-loader-v0 1.3.1+5b5275af19
# 	   |-- fabric-screen-api-v1 2.0.25+8b68f1c719
# 	   |-- fabric-screen-handler-api-v1 1.3.88+b559734419
# 	   |-- fabric-sound-api-v1 1.0.23+6573ed8c19
# 	   |-- fabric-transfer-api-v1 5.4.2+c24bd99419
# 	   \-- fabric-transitive-access-wideners-v1 6.2.0+45b9699719
# 	- fabricloader 0.16.10
# 	   \-- mixinextras 0.4.1
# 	- ferritecore 7.0.2-hotfix
# 	- java 21
# 	- krypton 0.2.8
# 	   \-- com_velocitypowered_velocity-native 3.3.0-SNAPSHOT
# 	- letmedespawn 1.4.4
# 	- lithium 0.14.7+mc1.21.1
# 	- minecraft 1.21.1
# 	- monsters_in_the_closet 1.0.3+1.21
# 	- mr_tims_ultimatelycomprehensivecobblemoneditsofdestiny 1.6.1-1
# 	- showmeyourskin 1.11.3+1.21
# 	   |-- cardinal-components-base 6.1.0
# 	   \-- cardinal-components-entity 6.1.0
# 	- slimyfloor 1.21-1.3.2
# 	- superflatworldnoslimes 3.4
# [15:02:00] [main/INFO]: SpongePowered MIXIN Subsystem Version=0.8.7 Source=file:/content/drive/MyDrive/Minecraft-server_Cobblemon/libraries/net/fabricmc/sponge-mixin/0.15.4+mixin.0.8.7/sponge-mixin-0.15.4+mixin.0.8.7.jar Service=Knot/Fabric Env=SERVER
# [15:02:00] [main/INFO]: Compatibility level set to JAVA_21
# [15:02:01] [main/WARN]: Mod 'ferritecore' attempted to override option 'mixin.alloc.blockstate', which doesn't exist, ignoring
# [15:02:01] [main/INFO]: Option 'mixin.entity.collisions.fluid' requires 'mixin.util.block_tracking=true' but found 'false'. Setting 'mixin.entity.collisions.fluid=false'.
# [15:02:01] [main/INFO]: Option 'mixin.experimental.entity.block_caching.suffocation' requires 'mixin.util.block_tracking=true' but found 'false'. Setting 'mixin.experimental.entity.block_caching.suffocation=false'.
# [15:02:01] [main/INFO]: Option 'mixin.experimental.entity.block_caching.block_support' requires 'mixin.util.block_tracking=true' but found 'false'. Setting 'mixin.experimental.entity.block_caching.block_support=false'.
# [15:02:01] [main/INFO]: Option 'mixin.experimental.entity.block_caching.fluid_pushing' requires 'mixin.util.block_tracking=true' but found 'false'. Setting 'mixin.experimental.entity.block_caching.fluid_pushing=false'.
# [15:02:01] [main/INFO]: Option 'mixin.experimental.entity.block_caching.block_touching' requires 'mixin.util.block_tracking=true' but found 'false'. Setting 'mixin.experimental.entity.block_caching.block_touching=false'.
# [15:02:01] [main/INFO]: Option 'mixin.experimental.entity.block_caching' requires 'mixin.util.block_tracking=true' but found 'false'. Setting 'mixin.experimental.entity.block_caching=false'.
# [15:02:01] [main/INFO]: Loaded configuration file for Lithium: 144 options available, 1 override(s) found
# [15:02:01] [main/WARN]: Error loading class: net/minecraft/class_350 (java.lang.ClassNotFoundException: net/minecraft/class_350)
# [15:02:01] [main/WARN]: @Mixin target net.minecraft.class_350 was not found mixins.cobblemon-common.json:accessor.EntryListWidgetAccessor from mod cobblemon
# [15:02:01] [main/WARN]: Error loading class: juuxel/adorn/block/variant/BlockVariantSets (java.lang.ClassNotFoundException: juuxel/adorn/block/variant/BlockVariantSets)
# [15:02:01] [main/WARN]: @Mixin target juuxel.adorn.block.variant.BlockVariantSets was not found mixins.cobblemon-common.json:invoker.AdornRegisterInvoker from mod cobblemon
# [15:02:02] [main/INFO]: Force-enabling mixin 'compat.transfer_api.TransferApiHelperMixin' as rule 'mixin.compat.transfer_api' (added by mods [lithium]) enables it
# [15:02:02] [main/WARN]: Error loading class: net/minecraft/class_310 (java.lang.ClassNotFoundException: net/minecraft/class_310)
# [15:02:02] [main/WARN]: @Mixin target net.minecraft.class_310 was not found monsters_in_the_closet.mixins.json:MinecraftClientMixin from mod monsters_in_the_closet
# [15:02:03] [main/INFO]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.4.1).
# [15:02:27] [main/INFO]: Booting LaxPermissionValidator, permissions will be checked using Minecrafts permission level system, see https://minecraft.fandom.com/wiki/Permission_level
# [15:02:27] [main/INFO]: Launching Cobblemon 1.6.1
# [15:02:28] [main/ERROR]: No data fixer registered for cobblemon:pokemon
# [15:02:28] [main/ERROR]: No data fixer registered for cobblemon:empty_pokeball
# [15:02:28] [main/ERROR]: No data fixer registered for cobblemon:boat
# [15:02:28] [main/ERROR]: No data fixer registered for cobblemon:chest_boat
# [15:02:28] [main/ERROR]: No data fixer registered for cobblemon:poke_bobber
# [15:02:28] [main/ERROR]: No data fixer registered for cobblemon:generic_bedrock
# [15:02:28] [main/ERROR]: No data fixer registered for cobblemon:npc
# [15:02:29] [main/INFO]: Starting the Best Spawner...
# [15:02:29] [main/INFO]: Loaded 7 spawning condition types.
# [15:02:29] [main/INFO]: Loaded 6 spawning context types.
# [15:02:29] [main/INFO]: Loaded 2 spawn detail types.
# [15:02:30] [Cobblemon Showdown/INFO]: Starting showdown service...
# [15:02:35] [Cobblemon Showdown/INFO]: Showdown has been started!
# [15:02:35] [main/INFO]: Note: Cobblemon data registries are only loaded once per server instance as Pokémon species are not safe to reload.
# [15:02:35] [main/INFO]: Registered the cobblemon:molang registry
# [15:02:35] [main/INFO]: Registered the cobblemon:species_features registry
# [15:02:35] [main/INFO]: Registered the cobblemon:global_species_features registry
# [15:02:35] [main/INFO]: Registered the cobblemon:species_feature_assignments registry
# [15:02:35] [main/INFO]: Registered the cobblemon:action_effects registry
# [15:02:35] [main/INFO]: Registered the cobblemon:moves registry
# [15:02:35] [main/INFO]: Registered the cobblemon:abilities registry
# [15:02:35] [main/INFO]: Registered the cobblemon:brain_presets registry
# [15:02:35] [main/INFO]: Registered the cobblemon:species registry
# [15:02:35] [main/INFO]: Registered the cobblemon:species_additions registry
# [15:02:35] [main/INFO]: Registered the cobblemon:pokeballs registry
# [15:02:35] [main/INFO]: Registered the cobblemon:properties_tab_completion registry
# [15:02:35] [main/INFO]: Registered the cobblemon:spawn_detail_presets registry
# [15:02:35] [main/INFO]: Registered the cobblemon:spawn_rules registry
# [15:02:35] [main/INFO]: Registered the cobblemon:mechanics registry
# [15:02:35] [main/INFO]: Registered the cobblemon:bag_items registry
# [15:02:36] [main/INFO]: Registered the cobblemon:dialogues registry
# [15:02:36] [main/INFO]: Registered the cobblemon:natural_materials registry
# [15:02:36] [main/INFO]: Registered the cobblemon:fossils registry
# [15:02:36] [main/INFO]: Registered the cobblemon:npc_preset registry
# [15:02:36] [main/INFO]: Registered the cobblemon:npc registry
# [15:02:36] [main/INFO]: Registered the cobblemon:dex_entries registry
# [15:02:36] [main/INFO]: Registered the cobblemon:dex_entry_additions registry
# [15:02:36] [main/INFO]: Registered the cobblemon:dexes registry
# [15:02:36] [main/INFO]: Registered the cobblemon:dex_additions registry
# [15:02:36] [main/INFO]: Registered the cobblemon:flows registry
# [15:02:36] [main/INFO]: Registered the cobblemon:spawn_pool_world registry
# [15:02:36] [main/INFO]: Registered the cobblemon:pokerods registry
# [15:02:36] [main/INFO]: Registered the cobblemon:berries registry
# [15:02:36] [main/INFO]: Registered the cobblemon:fishing_baits registry
# [15:02:37] [main/INFO]: Loading Collective version 7.87.
# [15:02:38] [main/INFO]: Compression will use libdeflate (Linux x86_64), encryption will use OpenSSL 3.0.x (Linux x86_64)
# [15:02:38] [main/INFO]: Krypton is now accelerating your Minecraft server's networking stack 🚀
# [15:02:38] [main/INFO]: SlimyFloor 1.21-1.3.2 loaded
# [15:02:39] [main/INFO]: Environment: Environment[sessionHost=https://sessionserver.mojang.com, servicesHost=https://api.minecraftservices.com, name=PROD]
# [15:02:45] [main/INFO]: Loaded 1782 recipes
# [15:02:45] [main/INFO]: Loaded 1925 advancements
# [15:02:45] [main/INFO]: Loaded 5 server scripts and 1 client scripts
# [15:02:56] [main/INFO]: Loaded 936 moves
# [15:02:56] [main/INFO]: Loaded 314 abilities
# [15:02:57] [main/INFO]: Finished additions
# [15:02:58] [cobblemon Datafixer Bootstrap/INFO]: 2 Datafixer optimizations took 20 milliseconds
# [15:03:00] [main/INFO]: Imported 259 held item IDs from showdown
# [15:03:00] [main/INFO]: Loaded 1025 Pokémon species
# [15:03:00] [main/INFO]: Loaded 25 spawn detail presets.
# [15:03:00] [main/INFO]: Starting dummy Showdown battle to force it to pre-load data.
# [15:03:01] [main/INFO]: Loaded 15 fossils
# [15:03:01] [main/ERROR]: Invalid path in mod resource-pack cobblemon: cobblemon:dex_entry_additions/README.md, ignoring
# [15:03:01] [main/ERROR]: Invalid path in mod resource-pack cobblemon: cobblemon:dex_additions/README.md, ignoring
# [15:03:01] [main/INFO]: Loaded 1 flows and 0 client flows
# [15:03:03] [main/INFO]: Loaded 69 berries
# [15:03:05] [main/INFO]: Applied 535 biome modifications to 64 of 64 new biomes in 89.52 ms
# [15:03:05] [Server thread/INFO]: Starting minecraft server version 1.21.1
# [15:03:05] [Server thread/INFO]: Loading properties
# [15:03:05] [Server thread/INFO]: Default game type: SURVIVAL
# [15:03:05] [Server thread/INFO]: Generating keypair
# [15:03:05] [Server thread/INFO]: Starting Minecraft server on *:25565
# [15:03:06] [Server thread/INFO]: Using epoll channel type
# [15:03:06] [Server thread/WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [15:03:06] [Server thread/WARN]: The server will make no attempt to authenticate usernames. Beware.
# [15:03:06] [Server thread/WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [15:03:06] [Server thread/WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [15:03:06] [Server thread/INFO]: Preparing level "world"
# [15:03:24] [Server thread/INFO]: Preparing start region for dimension minecraft:overworld
# [15:03:25] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [15:03:25] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [15:03:25] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [15:03:26] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [15:03:27] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [15:03:27] [Worker-Main-1/INFO]: Preparing spawn area: 2%
# [15:03:27] [Worker-Main-1/INFO]: Preparing spawn area: 2%
# [15:03:27] [Server thread/INFO]: Time elapsed: 3408 ms
# [15:03:27] [Server thread/INFO]: Done (21.273s)! For help, type "help"
# [15:03:39] [Server thread/INFO]: [STDOUT]: Lithium Cached BlockState Flags are disabled!
# [15:03:39] [Server thread/INFO]: black_shadow3127[/127.0.0.1:51506] logged in with entity id 9 at (-3093.181638352761, 79.0, -2079.372701732951)
# [15:03:39] [Server thread/INFO]: black_shadow3127 joined the game
# [15:03:43] [Server thread/INFO]: [showmeyourskin] Client of black_shadow3127 accepted server config.
# [15:03:43] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 4858ms or 97 ticks behind
# [15:03:53] [Server thread/INFO]: FISH[/127.0.0.1:55902] logged in with entity id 229 at (-3089.0779091110435, 78.0, -2002.3210559543463)
# [15:03:53] [Server thread/INFO]: FISH joined the game
# [15:03:54] [Server thread/INFO]: [showmeyourskin] Client of FISH accepted server config.
# [15:04:08] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 9477ms or 189 ticks behind
# [15:04:38] [Server thread/INFO]: FISH has made the advancement [Hard Work and Dedication]
# [15:07:07] [Server thread/WARN]: black_shadow3127 moved too quickly! -0.3662605132326462,0.0,-9.998328315872186
# [15:07:07] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 2255ms or 45 ticks behind
# [15:08:32] [Server thread/INFO]: black_shadow3127 has made the advancement [Sweet Tooth]
# [15:09:30] [Server thread/INFO]: black_shadow3127 has made the advancement [Hard Work and Dedication]
# [15:09:45] [Server thread/INFO]: FISH has made the advancement [Sweet Tooth]
# [15:10:24] [Server thread/INFO]: FISH has completed the challenge [Darwin? Who's That?]
# [15:10:37] [Server thread/INFO]: black_shadow3127 has completed the challenge [Darwin? Who's That?]
# [15:11:15] [Server thread/WARN]: FISH moved too quickly! -7.207258134372296,-3.3594124209233485,-6.199950535318521
# [15:14:17] [Server thread/INFO]: FISH has made the advancement [Where's my Victory Music?]
# [15:16:05] [Server thread/INFO]: Villager class_1646['Cartographer'/113, l='ServerLevel[world]', x=-3164.52, y=62.94, z=-2055.30] died, message: 'Cartographer was slain by Zombie'
# [15:23:23] [Server thread/WARN]: FISH moved too quickly! 8.07545744254594,-3.750000139400285,-6.298927213942989
# [15:30:03] [Server thread/WARN]: black_shadow3127 moved too quickly! 5.769767971940837,0.1876479425102957,-9.314783104230173
# [15:30:10] [Server thread/WARN]: FISH moved too quickly! 4.732841770491177,0.0,9.252833442986002
# [15:30:10] [Server thread/WARN]: black_shadow3127 moved too quickly! 4.570402681037649,5.204262602959382,-7.576804244575214
# [15:30:10] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 2492ms or 49 ticks behind
# [15:30:13] [Server thread/WARN]: FISH moved too quickly! 7.876022246047796,0.0,7.0338091844569135
# [15:30:17] [Server thread/INFO]: [black_shadow3127: Teleported black_shadow3127 to FISH]
# [15:30:38] [Server thread/INFO]: black_shadow3127 has made the advancement [Basic Healing]
# [15:31:04] [Server thread/WARN]: black_shadow3127 moved too quickly! -9.12853009630362,0.0,-4.853778780265657
# [15:31:45] [Server thread/INFO]: [black_shadow3127: Teleported black_shadow3127 to FISH]
# [15:32:46] [Server thread/WARN]: black_shadow3127 moved too quickly! -6.46567240838931,0.0,-8.26655027776792
# [15:33:38] [Server thread/WARN]: black_shadow3127 moved too quickly! -5.350556281845456,3.3750001340896176,8.070588257806776
# [15:34:08] [Server thread/WARN]: black_shadow3127 moved too quickly! -9.691495058470537,0.2888259715153083,-4.954459466205435
# [15:34:29] [Server thread/WARN]: FISH moved too quickly! 9.149508245989182,3.7500001429491334,2.1576433567477125
# [15:34:53] [Server thread/INFO]: Locating element minecraft:village_snowy took 6554 ms
# [15:34:53] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 6601ms or 132 ticks behind
# [15:34:53] [Server thread/WARN]: FISH moved too quickly! -2.5787814519180756,4.211679714810401,8.812791762977668
# [15:35:06] [Server thread/INFO]: [black_shadow3127: Teleported black_shadow3127 to -1247.500000, 100.000000, -4303.500000]
# [15:35:15] [Server thread/WARN]: black_shadow3127 moved too quickly! 0.0,-10.806526110008988,0.0
# [15:35:17] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 8956ms or 179 ticks behind
# [15:35:30] [Server thread/WARN]: FISH moved too quickly! 7.746660263715057,-2.446947937232963,-5.958032591363462
# [15:35:39] [Server thread/INFO]: Villager class_1646['Villager'/9629, l='ServerLevel[world]', x=-1244.37, y=75.56, z=-4317.72] died, message: 'Villager suffocated in a wall'
# [15:36:52] [Server thread/WARN]: black_shadow3127 moved too quickly! -0.7842798492779366,1.0104000401496904,-10.02644934746786
# [15:37:33] [Server thread/WARN]: black_shadow3127 moved too quickly! 8.905818958173995,0.0,6.0439807495949935
# [15:37:39] [Server thread/WARN]: Tried to load a DUMMY block entity @ class_2338{x=-1118, y=73, z=-4462} but found not block entity block Block{minecraft:air} at location
# [15:37:39] [Server thread/WARN]: Tried to load a block entity for block Block{minecraft:air} but failed at location class_2338{x=-1118, y=73, z=-4462}
# [15:37:39] [Server thread/WARN]: Tried to load a DUMMY block entity @ class_2338{x=-1119, y=72, z=-4462} but found not block entity block Block{minecraft:air} at location
# [15:37:39] [Server thread/WARN]: Tried to load a block entity for block Block{minecraft:air} but failed at location class_2338{x=-1119, y=72, z=-4462}
# [15:37:39] [Server thread/WARN]: Tried to load a DUMMY block entity @ class_2338{x=-1117, y=73, z=-4462} but found not block entity block Block{minecraft:air} at location
# [15:37:39] [Server thread/WARN]: Tried to load a block entity for block Block{minecraft:air} but failed at location class_2338{x=-1117, y=73, z=-4462}
# [15:38:04] [Server thread/WARN]: black_shadow3127 moved too quickly! 8.212268349324404,-2.651964584433429,5.955481161490752
# [15:38:04] [Server thread/WARN]: FISH moved too quickly! 8.837618969287632,2.7395054721121284,-5.490109084273172
# [15:38:50] [Server thread/WARN]: black_shadow3127 moved too quickly! 8.131985757743905,0.0,7.155394431392779
# [15:38:50] [Server thread/WARN]: FISH moved too quickly! -10.080325431460096,0.0,-2.5729755553777522
# [15:38:55] [Server thread/WARN]: FISH moved too quickly! -9.047086082265196,0.0,5.8268745795426184
# [15:39:06] [Server thread/WARN]: FISH moved too quickly! -2.0492174083610735,-3.749979135241418,9.491249079489762
# [15:39:59] [Server thread/INFO]: Locating element #c:is_aquatic (minecraft:river) took 21 ms
# [15:40:02] [Server thread/INFO]: [FISH: Teleported FISH to -2701.500000, 73.000000, -1525.500000]
# [15:41:12] [Server thread/INFO]: [black_shadow3127: Teleported black_shadow3127 to FISH]
# [15:41:39] [Server thread/WARN]: FISH moved too quickly! -2.695984546690397,0.0,-9.787954267998884
# [15:41:42] [Server thread/WARN]: black_shadow3127 moved too quickly! -0.49721747921921633,1.6490735995464476,9.967229627131701
# [15:41:42] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 3398ms or 67 ticks behind
# [15:42:10] [Server thread/WARN]: FISH moved too quickly! -2.711241915228584,-3.1216547083624846,-10.039965938063688
# [15:42:17] [Server thread/WARN]: black_shadow3127 moved too quickly! -5.35480741054289,3.620237052767969,-8.110154529487772
# [15:42:17] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 3808ms or 76 ticks behind
# [15:42:40] [Server thread/WARN]: black_shadow3127 moved too quickly! -9.430556597015766,0.0,-5.054041525202365
# [15:42:40] [Server thread/WARN]: FISH moved too quickly! 6.3088945077265635,0.0,-8.549924192622711
# [15:42:44] [Server thread/INFO]: [black_shadow3127: Teleported black_shadow3127 to FISH]
# [15:42:51] [Server thread/WARN]: FISH moved too quickly! 9.689177976648807,-1.3562400538921366,-4.379201924189829
# [15:43:56] [Server thread/WARN]: FISH moved too quickly! 4.704091650738519,5.162076290252969,-8.032503215354382
# [15:44:03] [Server thread/WARN]: FISH moved too quickly! 0.19173951194261463,3.3749058811695676,-9.459917489856934
# [15:44:34] [Server thread/INFO]: Locating element #c:is_icy (minecraft:ice_spikes) took 2904 ms
# [15:44:34] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 2875ms or 57 ticks behind
# [15:44:36] [Server thread/INFO]: [FISH: Teleported FISH to -1694.500000, 112.000000, -4150.500000]
# [15:44:44] [Server thread/WARN]: FISH moved too quickly! 0.0,-10.806526110008988,0.0
# [15:45:34] [Server thread/WARN]: FISH moved too quickly! 8.877858066430235,-2.8181688159839524,5.406167452434602
# [15:45:45] [Server thread/WARN]: FISH moved too quickly! -3.8505441145439363,-1.694850743749214,-10.18557169802807
# [15:48:38] [Server thread/WARN]: FISH moved too quickly! -5.014534061925133,4.124723132288082,-8.529112677551893
# [15:48:55] [Server thread/WARN]: FISH moved too quickly! -5.452615192833264,-0.19677577554723769,8.615888193960927
# [15:48:59] [Server thread/WARN]: FISH moved too quickly! -0.18449017943453327,-3.3747383203857453,-9.699179143873152
# [15:49:09] [Server thread/WARN]: FISH moved too quickly! 9.541015528108801,0.0,-5.243794193997019
# [15:49:19] [Server thread/WARN]: FISH moved too quickly! 8.375297568160704,0.0,5.6955483490091865
# [15:49:34] [Server thread/INFO]: Locating element minecraft:deep_ocean took 5194 ms
# [15:49:34] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 5183ms or 103 ticks behind
# [15:49:34] [Server thread/WARN]: black_shadow3127 moved too quickly! 4.450568722960725,-8.994302026405393,2.676714488628477
# [15:49:36] [Server thread/INFO]: [FISH: Teleported FISH to 1026.500000, 72.000000, -5687.500000]
# [15:49:43] [Server thread/WARN]: black_shadow3127 moved too quickly! 6.777831344808419,-6.937520841563526,3.188281256374694
# [15:49:50] [Server thread/WARN]: black_shadow3127 moved too quickly! 9.176327189338735,3.750000132992753,-4.702255139188992
# [15:50:16] [Server thread/INFO]: [black_shadow3127: Teleported black_shadow3127 to 1000.500000, 112.000000, 2313.500000]
# [15:50:33] [Server thread/WARN]: FISH moved too quickly! -0.5265993284951946,0.0,-10.1795625645791
# [15:50:33] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 16856ms or 337 ticks behind
# [15:50:44] [Server thread/WARN]: FISH moved too quickly! 2.222655182331664,7.970821113268258,-5.639126712126199
# [15:51:22] [Server thread/INFO]: [black_shadow3127: Set own game mode to Survival Mode]
# [15:51:35] [Server thread/INFO]: [black_shadow3127: Set own game mode to Creative Mode]
# [15:52:14] [Server thread/INFO]: Locating element minecraft:jungle took 3018 ms
# [15:52:14] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 3007ms or 60 ticks behind
# [15:52:23] [Server thread/INFO]: [black_shadow3127: Teleported black_shadow3127 to 2992.500000, 132.000000, 339.500000]
# [15:52:35] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 6082ms or 121 ticks behind
# [15:55:54] [Server thread/INFO]: [FISH: Teleported FISH to black_shadow3127]
# [15:58:12] [Server thread/WARN]: FISH moved too quickly! -8.089366763537782,-3.6000000194489985,5.372668437763622
# [15:58:26] [Server thread/INFO]: Locating element minecraft:stronghold took 363 ms
# [15:58:28] [Server thread/INFO]: [FISH: Teleported FISH to 1984.500000, 147.069228, -1599.500000]
# [15:58:38] [Server thread/INFO]: [FISH: Set own game mode to Spectator Mode]
# [15:58:38] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 9458ms or 189 ticks behind
# [15:58:39] [Server thread/INFO]: [black_shadow3127: Teleported black_shadow3127 to FISH]
# [15:58:57] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 4561ms or 91 ticks behind
# [15:59:13] [Server thread/WARN]: FISH moved too quickly! -8.871456853029486,-3.750000149011612,3.875065605845748
# [15:59:32] [Server thread/INFO]: [black_shadow3127: Teleported black_shadow3127 to FISH]
# [15:59:47] [Server thread/INFO]: FISH has made the advancement [Eye Spy]
# [15:59:51] [Server thread/INFO]: black_shadow3127 has made the advancement [Eye Spy]
# [15:59:57] [Server thread/INFO]: [black_shadow3127: Teleported black_shadow3127 to FISH]
# [15:59:58] [Server thread/INFO]: [FISH: Set own game mode to Creative Mode]
# [16:00:18] [Server thread/INFO]: FISH has made the advancement [The End?]
# [16:00:18] [Server thread/INFO]: black_shadow3127 has made the advancement [The End?]
# [16:00:24] [Server thread/INFO]: Scanning for legacy world dragon fight...
# [16:00:24] [Server thread/INFO]: Found that the dragon has not yet been killed in this world.
# [16:00:25] [Server thread/WARN]: Can't keep up! Is the server overloaded? Running 8857ms or 177 ticks behind
# [16:01:57] [Server thread/WARN]: black_shadow3127 moved too quickly! 1.7221356363851896,-3.3587830971228954,-9.50187437845408
# [16:02:17] [Server thread/WARN]: FISH moved too quickly! -9.886979986723343,0.0,-3.3695892134896854
# [16:03:09] [Server thread/INFO]: black_shadow3127 lost connection: Disconnected
# [16:03:09] [Server thread/INFO]: black_shadow3127 left the game
# [16:03:09] [Server thread/INFO]: FISH lost connection: Disconnected
# [16:03:09] [Server thread/INFO]: FISH left the game
# ✅ Minecraft server closed!
