# %% [markdown]
# # 🎮 **Create a Minecraft Server on Google Colab!**
# 🚀 Set up and run your own **Minecraft server** effortlessly!
#
# ---
#
# ## 📌 **How It Works:**
# ✔️ **The script below will initiate your server.**
# ✔️ **First, you'll need to create the server** before running it.
# ✔️ **No worries!** The scripts below will handle most of the setup for you.
#
# 💡 **Want to change the server's region?** Check the instructions below.
#
# ---
#
# ## 🔗 **Original Repository:**
# [GitHub - agrawalchaitany/minecolab](https://github.com/agrawalchaitany/minecolab.git)
#
# ## ⚡ **Modified Version:**
# ✅ **Well-Optimized for Performance**
#
# ---
#
#
#
# ```
# ███╗   ███╗██╗███╗   ██╗███████╗ ██████╗ ██████╗ ██╗      █████╗ ██████╗
# ████╗ ████║██║████╗  ██║██╔════╝██╔════╝██╔═══██╗██║     ██╔══██╗██╔══██╗
# ██╔████╔██║██║██╔██╗ ██║█████╗  ██║     ██║   ██║██║     ███████║██████╔╝
# ██║╚██╔╝██║██║██║╚██╗██║██╔══╝  ██║     ██║   ██║██║     ██╔══██║██╔══██╗
# ██║ ╚═╝ ██║██║██║ ╚████║███████╗╚██████╗╚██████╔╝███████╗██║  ██║██████╔╝
# ╚═╝     ╚═╝╚═╝╚═╝  ╚═══╝╚══════╝ ╚═════╝ ╚═════╝ ╚══════╝╚═╝  ╚═╝╚═════╝
#
# ```
#
# 🎉 **Enjoy your Minecraft server on Google Colab!**

# %% [markdown]
# # 🛠️ **Step 1: Create the Server (First-Time Setup Only)**
# 🚀 **Run this step only once** to set up your server and accept the EULA.
#
# ---
#
# ## 📌 **What This Does:**
# ✔️ Creates your **Minecraft server**
# ✔️ Automatically **accepts the EULA**
# ✔️ Prepares the server for **quick startup**
#
# ---
#
# 🎮 **After this, your server will be ready to launch!** 🚀

# %% [markdown]
# # ⬇️ **Download the Prominence II RPG v3.1.1 Server**
# 🚀 A **high-performance Fabric server** for an enhanced gaming experience!
#
# ---
#
# ## 📌 **About**
# The code below will **download** the **Prominence II RPG v3.1.1** server.
#
# 📂 **Storage Location:**
# The server files will be **saved on your Google Drive**
# (Linked to the Google account you choose or are currently using).
#
# ---
#
# ✅ **Enjoy seamless performance with Fabric!**

# %%
"""
=============================================
      🌟 Prominence II RPG v3.1.1 🌟
=============================================

📌 Developed by:      ElocinDev
📌 Release Type:      R
📌 Release Date:      February 6, 2025
📌 File Size:         66.54 MB
📌 Downloads:         146.2K

🎮 Supported Versions:
   - Minecraft 1.20.1
   - Minecraft 1.20

🛠️ Mod Loader:       Fabric
🗂️ File Name:        Prominence II RPG Hasturian Era-v3.1.1.zip
🆙 Version Code:     1.20.1+1

=============================================
"""



import requests
import json
import os
import shutil
from google.colab import drive

# Mount Google Drive
drive.mount("/content/drive")

# Configuration
MINECRAFT_VERSION = "1.20.1"
SERVER_TYPE = "Prominence_II_RPG_Hasturian_Era"
SERVER_DIR = "/content/drive/My Drive/Minecraft-server_Prominence_II_RPG_Hasturian_Era"
os.makedirs(SERVER_DIR, exist_ok=True)


# download URLs
server_urls = {
    "Prominence_II_RPG_Hasturian_Era": "https://www.curseforge.com/api/v1/mods/466901/files/6162020/download",
}
file_name ={
    "Prominence_II_RPG_Hasturian_Era": "Prominence_II_RPG_Hasturian_Era.zip",
}

download_url = server_urls.get(SERVER_TYPE)
zip_file="/content/drive/My Drive/Minecraft-server_Prominence_II_RPG_Hasturian_Era/Prominence_II_RPG_Hasturian_Era.zip"
# Download the selected server
if download_url:
    print(f"Downloading {SERVER_TYPE} server from {download_url}...")
    response = requests.get(download_url)

    if response.status_code == 200:
        with open(os.path.join(SERVER_DIR, file_name[SERVER_TYPE]), "wb") as f:
          f.write(response.content)
        shutil.unpack_archive(zip_file, SERVER_DIR)
        print("unzip successfully.")
        print(f"{SERVER_TYPE} server downloaded successfully.")
    else:
        print(f"Failed to download {SERVER_TYPE} server. Status code: {response.status_code}")
else:
    print(f"Invalid server type or missing URL: {SERVER_TYPE}")

os.system("bash start.sh")

# Save configuration
config_data = {"server_type": SERVER_TYPE, "server_version": MINECRAFT_VERSION }
with open(os.path.join(SERVER_DIR, "colabconfig.json"), "w") as config_file:
    json.dump(config_data, config_file)

print("Setup complete!")

# Accept Minecraft EULA
eula_path = os.path.join(SERVER_DIR, "eula.txt")
with open(eula_path, "w") as eula_file:
    eula_file.write("eula=true\n")

print("EULA accepted. Ready to start the server!")
# Out:
# ERROR: Could not find a version that satisfies the requirement shutil (from versions: none)
# ERROR: No matching distribution found for shutil
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading Prominence_II_RPG_Hasturian_Era server from https://www.curseforge.com/api/v1/mods/466901/files/6162020/download...
# unzip successfully.
# Prominence_II_RPG_Hasturian_Era server downloaded successfully.
# Setup complete!
# EULA accepted. Ready to start the server!

# %% [markdown]
# # 🚀 **Start the Minecraft Server**
# 💡 **Use this whenever you want to open it.**
#
# ---
#
# ## ⚠️ **Note:**
# 🔹 In **`variable.txt`**, modify the following line:
#
# ```bash
# JAVA_ARGS="-Xmx12G -Xms12G"

# %%
import os
import time
import json
import re
from google.colab import drive

# 🛠️ Update package lists
print("\n🔄 Updating package lists...")
os.system("sudo apt update &>/dev/null && echo '✅ apt cache successfully updated' || echo '❌ apt cache update failed.'")

# 📂 Mount Google Drive
print("\n🔗 Mounting Google Drive...")
drive.mount('/content/drive')

# 🎮 Change directory to Minecraft server folder
server_path = "/content/drive/My Drive/Minecraft-server_Prominence_II_RPG_Hasturian_Era"
if os.path.exists(server_path):
    os.chdir(server_path)
    print(f"✅ Changed working directory to: {server_path}")
    print("📂 Listing server files:\n")
    # !ls
else:
    print(f"❌ Error: {server_path} not found. Make sure the folder exists in Google Drive.")
    exit()

# 🔧 Load or create configuration file
config_file = "colabconfig.json"
if os.path.isfile(config_file):
    with open(config_file, "r") as f:
        colabconfig = json.load(f)
else:
    colabconfig = {"server_type": "generic"}
    with open(config_file, "w") as f:
        json.dump(colabconfig, f)

server_type = colabconfig.get("server_type", "generic")


# 🌍 tunneling service availble
#  -nglocalhost
#  -pinggy

# 🌍 Setup tunneling service
tunnel_service = "pinggy"  # Can be changed to "pinggy" if needed
print(f"\n🌍 Using {tunnel_service} for server tunneling...")
key_path = "/content/drive/My Drive/Minecraft-server_Prominence_II_RPG_Hasturian_Era/ssh_keys/id_rsa"

# ⏳ Generate SSH key if missing.
def generate_ssh_key(key_path):

    if not os.path.isfile(key_path):
        os.makedirs(os.path.dirname(key_path), exist_ok=True)
        os.system(f"ssh-keygen -t rsa -b 4096 -f '{key_path}' -N '' -q")
        os.system(f"chmod 400 '{key_path}'")
        os.system(f"ssh-keygen -lf '{key_path}.pub' > '{key_path}_fingerprint.txt'")

print(f"\n🔌 Setting up {tunnel_service} tunneling...")

# 🔌 Establishing the tunnel
if tunnel_service == "nglocalhost":

    # ⏳ Generate SSH key if missing
    generate_ssh_key(key_path)

    # Establish tunnel
    print("⏳ Establishing tunnel, please wait...")
    os.system("nohup ssh -T -o StrictHostKeyChecking=no -i '/content/drive/My Drive/Minecraft-server_Prominence_II_RPG_Hasturian_Era/ssh_keys/id_rsa' -R minecraft03127:25565:localhost:25565 nglocalhost.com > tunnel_log.txt 2>&1 &")
    url_pattern=r"(nglocalhost:[^\s]+)"
    # Wait for tunnel to establish
    time.sleep(10)

elif tunnel_service == "pinggy":

    # ⏳ Generate SSH key if missing
    generate_ssh_key(key_path)

    # Establish tunnel
    print("⏳ Establishing tunnel, please wait...")
    os.system("nohup ssh -p 443 -o StrictHostKeyChecking=no -o ServerAliveInterval=30 -R0:127.0.0.1:25565 tcp@ap.a.pinggy.io > tunnel_log.txt 2>&1 &")
    url_pattern=r"(tcp://[^\s]+)"
    # Wait for tunnel to establish
    time.sleep(10)

else:
    print("⚠️ No tunneling service selected. Server will run locally.")

# Extract and display the tunnel URL
with open("tunnel_log.txt", "r") as log_file:
    log_content = log_file.read()
    match = re.search(url_pattern, log_content)  # Extract first URL
    if match:
        tunnel_url = match.group(0)
        print(f"✅ Tunnel established! Access your Minecraft server at:\n🌍 {tunnel_url}")
    else:
        print("⚠️ Could not extract tunnel URL. Check 'tunnel_log.txt' manually.")

# 🚀 Start Minecraft server
print("\n🚀 Starting Minecraft server...")
# !bash start.sh
print("✅ Minecraft server closed!")
# Out:
# Streaming output truncated to the last 5000 lines.
# 		org.embeddedt.modernfix.fabric.mixin.core.MinecraftServerMixin (modernfix-fabric.mixins.json)
# 		io.github.thecsdev.tcdcommons.mixin.events.MixinMinecraftServer (tcdcommons.mixin.events.json)
# 		com.chaosthedude.naturescompass.mixins.ServerMixin (naturescompass.mixins.json)
# 		io.github.fabricators_of_create.porting_lib.mixin.accessors.common.accessor.MinecraftServerAccessor (porting_lib_accessors.mixins.json)
# 		com.archers_expansion.mixin.ExampleMixin (archers-expansion.mixins.json)
# 		elocindev.eldritch_end.mixin.server.BiomeMixin (eldritch_end.mixins.json)
# 		com.terraformersmc.biolith.impl.mixin.MixinMinecraftServer (biolith.mixins.json)
# 		net.fabricmc.fabric.mixin.registry.sync.MinecraftServerMixin (fabric-registry-sync-v0.mixins.json)
# 		dev.shadowsoffire.placebo.mixin.getters.MinecraftServerAccessor (fakerlib.mixins.json)
# 		org.embeddedt.modernfix.common.mixin.perf.dedicated_reload_executor.MinecraftServerMixin (modernfix-common.mixins.json)
# 		net.fabricmc.fabric.mixin.message.MinecraftServerMixin (fabric-message-api-v1.mixins.json)
# 		terrablender.mixin.MixinMinecraftServer (terrablender_fabric.mixins.json)
# 		appeng.mixins.spatial.MinecraftServerMixin (ae2.mixins.json)
# 		dev.onyxstudios.cca.mixin.scoreboard.MixinMinecraftServer (mixins.cardinal_components_scoreboard.json)
# 		xaero.pac.common.mixin.MixinMinecraftServer (openpartiesandclaims.mixins.json)
# 		net.redstonegames.chefsdelight.mixin.ExampleMixin (chefsdelight.mixins.json)
# 		net.fabricmc.fabric.mixin.event.lifecycle.MinecraftServerMixin (fabric-lifecycle-events-v1.mixins.json)
# 		cn.foggyhillside.ends_delight.mixin.EndsDelightMixin (ends_delight.mixins.json)
# 		xaero.map.mixin.MixinMinecraftServer (xaeroworldmap.mixins.json)
#
# -- Thread Dump --
# Details:
# 	Threads: "Reference Handler" daemon prio=10 Id=2 RUNNABLE
# 	at java.base@17.0.14/java.lang.ref.Reference.waitForReferencePendingList(Native Method)
# 	at java.base@17.0.14/java.lang.ref.Reference.processPendingReferences(Reference.java:253)
# 	at java.base@17.0.14/java.lang.ref.Reference$ReferenceHandler.run(Reference.java:215)
#
#
# "Finalizer" daemon prio=8 Id=3 WAITING on java.lang.ref.ReferenceQueue$Lock@7fcd769f
# 	at java.base@17.0.14/java.lang.Object.wait(Native Method)
# 	-  waiting on java.lang.ref.ReferenceQueue$Lock@7fcd769f
# 	at java.base@17.0.14/java.lang.ref.ReferenceQueue.remove(ReferenceQueue.java:155)
# 	at java.base@17.0.14/java.lang.ref.ReferenceQueue.remove(ReferenceQueue.java:176)
# 	at java.base@17.0.14/java.lang.ref.Finalizer$FinalizerThread.run(Finalizer.java:172)
#
#
# "Signal Dispatcher" daemon prio=9 Id=4 RUNNABLE
#
#
# "Notification Thread" daemon prio=9 Id=10 RUNNABLE
#
#
# "Common-Cleaner" daemon prio=8 Id=11 TIMED_WAITING on java.lang.ref.ReferenceQueue$Lock@710a8716
# 	at java.base@17.0.14/java.lang.Object.wait(Native Method)
# 	-  waiting on java.lang.ref.ReferenceQueue$Lock@710a8716
# 	at java.base@17.0.14/java.lang.ref.ReferenceQueue.remove(ReferenceQueue.java:155)
# 	at java.base@17.0.14/jdk.internal.ref.CleanerImpl.run(CleanerImpl.java:140)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
# 	at java.base@17.0.14/jdk.internal.misc.InnocuousThread.run(InnocuousThread.java:162)
#
#
# "FileSystemWatchService" daemon prio=5 Id=20 RUNNABLE (in native)
# 	at java.base@17.0.14/sun.nio.fs.LinuxWatchService.poll(Native Method)
# 	at java.base@17.0.14/sun.nio.fs.LinuxWatchService$Poller.run(LinuxWatchService.java:314)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "JNA Cleaner" daemon prio=5 Id=22 WAITING on java.lang.ref.ReferenceQueue$Lock@75351def
# 	at java.base@17.0.14/java.lang.Object.wait(Native Method)
# 	-  waiting on java.lang.ref.ReferenceQueue$Lock@75351def
# 	at java.base@17.0.14/java.lang.ref.ReferenceQueue.remove(ReferenceQueue.java:155)
# 	at java.base@17.0.14/java.lang.ref.ReferenceQueue.remove(ReferenceQueue.java:176)
# 	at knot//com.sun.jna.internal.Cleaner$1.run(Cleaner.java:58)
#
#
# "FileSystemWatchService" daemon prio=5 Id=23 RUNNABLE (in native)
# 	at java.base@17.0.14/sun.nio.fs.LinuxWatchService.poll(Native Method)
# 	at java.base@17.0.14/sun.nio.fs.LinuxWatchService$Poller.run(LinuxWatchService.java:314)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "Auto-Sync thread" prio=5 Id=24 TIMED_WAITING on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@30378d2d
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@30378d2d
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.parkNanos(LockSupport.java:252)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject.awaitNanos(AbstractQueuedSynchronizer.java:1679)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:1182)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:899)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.getTask(ThreadPoolExecutor.java:1062)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1122)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:635)
# 	...
#
#
# "Thread-3" daemon prio=5 Id=25 TIMED_WAITING
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.parkNanos(LockSupport.java:376)
# 	at knot//com.electronwill.nightconfig.core.file.FileWatcher$WatcherThread.run(FileWatcher.java:190)
#
#
# "FileSystemWatchService" daemon prio=5 Id=26 RUNNABLE (in native)
# 	at java.base@17.0.14/sun.nio.fs.LinuxWatchService.poll(Native Method)
# 	at java.base@17.0.14/sun.nio.fs.LinuxWatchService$Poller.run(LinuxWatchService.java:314)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "Cicada thread 0" daemon prio=5 Id=27 WAITING on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@245a6c3a
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@245a6c3a
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.park(LockSupport.java:341)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionNode.block(AbstractQueuedSynchronizer.java:506)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.unmanagedBlock(ForkJoinPool.java:3465)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.managedBlock(ForkJoinPool.java:3436)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject.await(AbstractQueuedSynchronizer.java:1630)
# 	at java.base@17.0.14/java.util.concurrent.LinkedBlockingQueue.take(LinkedBlockingQueue.java:435)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.getTask(ThreadPoolExecutor.java:1062)
# 	...
#
#
# "Cicada thread 1" daemon prio=5 Id=28 WAITING on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@245a6c3a
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@245a6c3a
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.park(LockSupport.java:341)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionNode.block(AbstractQueuedSynchronizer.java:506)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.unmanagedBlock(ForkJoinPool.java:3465)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.managedBlock(ForkJoinPool.java:3436)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject.await(AbstractQueuedSynchronizer.java:1630)
# 	at java.base@17.0.14/java.util.concurrent.LinkedBlockingQueue.take(LinkedBlockingQueue.java:435)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.getTask(ThreadPoolExecutor.java:1062)
# 	...
#
#
# "Cicada thread 2" daemon prio=5 Id=29 WAITING on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@245a6c3a
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@245a6c3a
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.park(LockSupport.java:341)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionNode.block(AbstractQueuedSynchronizer.java:506)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.unmanagedBlock(ForkJoinPool.java:3465)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.managedBlock(ForkJoinPool.java:3436)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject.await(AbstractQueuedSynchronizer.java:1630)
# 	at java.base@17.0.14/java.util.concurrent.LinkedBlockingQueue.take(LinkedBlockingQueue.java:435)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.getTask(ThreadPoolExecutor.java:1062)
# 	...
#
#
# "Cicada thread 3" daemon prio=5 Id=30 WAITING on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@245a6c3a
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@245a6c3a
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.park(LockSupport.java:341)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionNode.block(AbstractQueuedSynchronizer.java:506)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.unmanagedBlock(ForkJoinPool.java:3465)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.managedBlock(ForkJoinPool.java:3436)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject.await(AbstractQueuedSynchronizer.java:1630)
# 	at java.base@17.0.14/java.util.concurrent.LinkedBlockingQueue.take(LinkedBlockingQueue.java:435)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.getTask(ThreadPoolExecutor.java:1062)
# 	...
#
#
# "FileSystemWatchService" daemon prio=5 Id=35 RUNNABLE (in native)
# 	at java.base@17.0.14/sun.nio.fs.LinuxWatchService.poll(Native Method)
# 	at java.base@17.0.14/sun.nio.fs.LinuxWatchService$Poller.run(LinuxWatchService.java:314)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "Auto-Sync thread" prio=5 Id=36 TIMED_WAITING on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@1cd7d90
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@1cd7d90
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.parkNanos(LockSupport.java:252)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject.awaitNanos(AbstractQueuedSynchronizer.java:1679)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:1182)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:899)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.getTask(ThreadPoolExecutor.java:1062)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1122)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:635)
# 	...
#
#
# "DFU cleaning thread" daemon prio=1 Id=37 TIMED_WAITING
# 	at java.base@17.0.14/java.lang.Thread.sleep(Native Method)
# 	at knot//org.embeddedt.modernfix.dfu.DFUBlaster$CleanerThread.run(DFUBlaster.java:59)
#
#
# "pool-3-thread-1" prio=5 Id=49 TIMED_WAITING on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@5c4ac223
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@5c4ac223
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.parkNanos(LockSupport.java:252)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject.awaitNanos(AbstractQueuedSynchronizer.java:1679)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:1182)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:899)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.getTask(ThreadPoolExecutor.java:1062)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1122)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:635)
# 	...
#
#
# "FileSystemWatchService" daemon prio=5 Id=50 RUNNABLE (in native)
# 	at java.base@17.0.14/sun.nio.fs.LinuxWatchService.poll(Native Method)
# 	at java.base@17.0.14/sun.nio.fs.LinuxWatchService$Poller.run(LinuxWatchService.java:314)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "Timer hack thread" daemon prio=5 Id=59 TIMED_WAITING
# 	at java.base@17.0.14/java.lang.Thread.sleep(Native Method)
# 	at knot//net.minecraft.class_156$9.run(class_156.java:839)
#
#
# "FileSystemWatchService" daemon prio=5 Id=60 RUNNABLE (in native)
# 	at java.base@17.0.14/sun.nio.fs.LinuxWatchService.poll(Native Method)
# 	at java.base@17.0.14/sun.nio.fs.LinuxWatchService$Poller.run(LinuxWatchService.java:314)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "Yggdrasil Key Fetcher" daemon prio=5 Id=61 TIMED_WAITING on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@50187262
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@50187262
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.parkNanos(LockSupport.java:252)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject.awaitNanos(AbstractQueuedSynchronizer.java:1679)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:1182)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:899)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.getTask(ThreadPoolExecutor.java:1062)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1122)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:635)
# 	...
#
#
# "Server thread" prio=5 Id=68 RUNNABLE
# 	at knot//dev.emi.trinkets.api.LivingEntityTrinketComponent.isEquipped(LivingEntityTrinketComponent.java:26)
# 	at knot//artifacts.fabric.platform.FabricPlatformHelper.lambda$isEquippedBy$0(FabricPlatformHelper.java:45)
# 	at knot//artifacts.fabric.platform.FabricPlatformHelper$$Lambda$29765/0x0000786c536d2c30.apply(Unknown Source)
# 	at java.base@17.0.14/java.util.Optional.map(Optional.java:260)
# 	at knot//artifacts.fabric.platform.FabricPlatformHelper.isEquippedBy(FabricPlatformHelper.java:45)
# 	at knot//artifacts.platform.PlatformHelper.isEquippedBy(PlatformHelper.java:23)
# 	at knot//artifacts.item.wearable.WearableArtifactItem.isEquippedBy(WearableArtifactItem.java:44)
# 	at knot//artifacts.item.wearable.feet.SnowshoesItem.getModifiedFriction(SnowshoesItem.java:30)
# 	...
#
#
# "DestroyJavaVM" prio=5 Id=70 RUNNABLE
#
#
# "FileSystemWatchService" daemon prio=5 Id=71 RUNNABLE (in native)
# 	at java.base@17.0.14/sun.nio.fs.LinuxWatchService.poll(Native Method)
# 	at java.base@17.0.14/sun.nio.fs.LinuxWatchService$Poller.run(LinuxWatchService.java:314)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "ComputerCraft-Network-0" daemon prio=3 Id=72 TIMED_WAITING on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@2754ffe7
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@2754ffe7
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.parkNanos(LockSupport.java:252)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject.awaitNanos(AbstractQueuedSynchronizer.java:1679)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:1182)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:899)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.getTask(ThreadPoolExecutor.java:1062)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1122)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:635)
# 	...
#
#
# "ComputerCraft-Network-1" daemon prio=3 Id=73 WAITING on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@2754ffe7
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@2754ffe7
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.park(LockSupport.java:341)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionNode.block(AbstractQueuedSynchronizer.java:506)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.unmanagedBlock(ForkJoinPool.java:3465)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.managedBlock(ForkJoinPool.java:3436)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject.await(AbstractQueuedSynchronizer.java:1630)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:1177)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:899)
# 	...
#
#
# "ComputerCraft-Network-2" daemon prio=3 Id=74 WAITING on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@2754ffe7
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@2754ffe7
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.park(LockSupport.java:341)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionNode.block(AbstractQueuedSynchronizer.java:506)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.unmanagedBlock(ForkJoinPool.java:3465)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.managedBlock(ForkJoinPool.java:3436)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject.await(AbstractQueuedSynchronizer.java:1630)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:1177)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:899)
# 	...
#
#
# "ComputerCraft-Network-3" daemon prio=3 Id=76 WAITING on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@2754ffe7
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@2754ffe7
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.park(LockSupport.java:341)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionNode.block(AbstractQueuedSynchronizer.java:506)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.unmanagedBlock(ForkJoinPool.java:3465)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.managedBlock(ForkJoinPool.java:3436)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject.await(AbstractQueuedSynchronizer.java:1630)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:1177)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:899)
# 	...
#
#
# "spark-monitoring-thread" daemon prio=5 Id=77 TIMED_WAITING on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@4d1f2760
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@4d1f2760
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.parkNanos(LockSupport.java:252)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject.awaitNanos(AbstractQueuedSynchronizer.java:1679)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:1182)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:899)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.getTask(ThreadPoolExecutor.java:1062)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1122)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:635)
# 	...
#
#
# "spark-worker-pool-1-thread-1" daemon prio=5 Id=78 WAITING on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@474eaf3a
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@474eaf3a
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.park(LockSupport.java:341)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionNode.block(AbstractQueuedSynchronizer.java:506)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.unmanagedBlock(ForkJoinPool.java:3465)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.managedBlock(ForkJoinPool.java:3436)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject.await(AbstractQueuedSynchronizer.java:1630)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:1170)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:899)
# 	...
#
#
# "spark-async-sampler-worker-thread" prio=5 Id=81 TIMED_WAITING on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@54564ed3
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject@54564ed3
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.parkNanos(LockSupport.java:252)
# 	at java.base@17.0.14/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject.awaitNanos(AbstractQueuedSynchronizer.java:1679)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:1182)
# 	at java.base@17.0.14/java.util.concurrent.ScheduledThreadPoolExecutor$DelayedWorkQueue.take(ScheduledThreadPoolExecutor.java:899)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.getTask(ThreadPoolExecutor.java:1062)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1122)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:635)
# 	...
#
#
# "Server console handler" daemon prio=5 Id=82 RUNNABLE (in native)
# 	at java.base@17.0.14/java.io.FileInputStream.readBytes(Native Method)
# 	at java.base@17.0.14/java.io.FileInputStream.read(FileInputStream.java:276)
# 	at java.base@17.0.14/java.io.BufferedInputStream.read1(BufferedInputStream.java:282)
# 	at java.base@17.0.14/java.io.BufferedInputStream.read(BufferedInputStream.java:343)
# 	-  locked java.io.BufferedInputStream@547d3879
# 	at java.base@17.0.14/sun.nio.cs.StreamDecoder.readBytes(StreamDecoder.java:287)
# 	at java.base@17.0.14/sun.nio.cs.StreamDecoder.implRead(StreamDecoder.java:330)
# 	at java.base@17.0.14/sun.nio.cs.StreamDecoder.read(StreamDecoder.java:190)
# 	-  locked java.io.InputStreamReader@60ed31b1
# 	at java.base@17.0.14/java.io.InputStreamReader.read(InputStreamReader.java:177)
# 	...
#
#
# "Netty Epoll Server IO #0" daemon prio=5 Id=87 RUNNABLE (in native)
# 	at knot//io.netty.channel.epoll.Native.epollWait(Native Method)
# 	at knot//io.netty.channel.epoll.Native.epollWait(Native.java:209)
# 	at knot//io.netty.channel.epoll.Native.epollWait(Native.java:202)
# 	at knot//io.netty.channel.epoll.EpollEventLoop.epollWaitNoTimerChange(EpollEventLoop.java:306)
# 	at knot//io.netty.channel.epoll.EpollEventLoop.run(EpollEventLoop.java:363)
# 	at knot//io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at knot//io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "Netty Epoll Server IO #1" daemon prio=5 Id=88 RUNNABLE (in native)
# 	at knot//io.netty.channel.epoll.Native.epollWait(Native Method)
# 	at knot//io.netty.channel.epoll.Native.epollWait(Native.java:209)
# 	at knot//io.netty.channel.epoll.Native.epollWait(Native.java:202)
# 	at knot//io.netty.channel.epoll.EpollEventLoop.epollWaitNoTimerChange(EpollEventLoop.java:306)
# 	at knot//io.netty.channel.epoll.EpollEventLoop.run(EpollEventLoop.java:363)
# 	at knot//io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at knot//io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "Thread-17" prio=5 Id=89 TIMED_WAITING
# 	at java.base@17.0.14/java.lang.Thread.sleep(Native Method)
# 	at knot//xaero.pac.common.server.io.IOThreadWorker.run(IOThreadWorker.java:60)
# 	-  locked xaero.pac.common.server.io.IOThreadWorker@52e865e9
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "nioEventLoopGroup-2-1" prio=10 Id=90 RUNNABLE (in native)
# 	at java.base@17.0.14/sun.nio.ch.EPoll.wait(Native Method)
# 	at java.base@17.0.14/sun.nio.ch.EPollSelectorImpl.doSelect(EPollSelectorImpl.java:118)
# 	at java.base@17.0.14/sun.nio.ch.SelectorImpl.lockAndDoSelect(SelectorImpl.java:129)
# 	-  locked io.netty.channel.nio.SelectedSelectionKeySet@34ae89b1
# 	-  locked sun.nio.ch.EPollSelectorImpl@9add1ad
# 	at java.base@17.0.14/sun.nio.ch.SelectorImpl.select(SelectorImpl.java:141)
# 	at knot//io.netty.channel.nio.SelectedSelectionKeySetSelector.select(SelectedSelectionKeySetSelector.java:62)
# 	at knot//io.netty.channel.nio.NioEventLoop.select(NioEventLoop.java:883)
# 	at knot//io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:526)
# 	at knot//io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	...
#
#
# "Server Watchdog" daemon prio=5 Id=97 RUNNABLE
# 	at java.management@17.0.14/sun.management.ThreadImpl.dumpThreads0(Native Method)
# 	at java.management@17.0.14/sun.management.ThreadImpl.dumpAllThreads(ThreadImpl.java:528)
# 	at java.management@17.0.14/sun.management.ThreadImpl.dumpAllThreads(ThreadImpl.java:516)
# 	at knot//net.minecraft.class_3178.run(class_3178.java:47)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "Netty Epoll Server IO #2" daemon prio=5 Id=104 RUNNABLE (in native)
# 	at knot//io.netty.channel.epoll.Native.epollWait(Native Method)
# 	at knot//io.netty.channel.epoll.Native.epollWait(Native.java:209)
# 	at knot//io.netty.channel.epoll.Native.epollWait(Native.java:202)
# 	at knot//io.netty.channel.epoll.EpollEventLoop.epollWaitNoTimerChange(EpollEventLoop.java:306)
# 	at knot//io.netty.channel.epoll.EpollEventLoop.run(EpollEventLoop.java:363)
# 	at knot//io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at knot//io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "Netty Epoll Server IO #3" daemon prio=5 Id=105 RUNNABLE
# 	at knot//io.netty.channel.epoll.Native.epollWait0(Native Method)
# 	at knot//io.netty.channel.epoll.Native.epollWait(Native.java:182)
# 	at knot//io.netty.channel.epoll.EpollEventLoop.epollWait(EpollEventLoop.java:302)
# 	at knot//io.netty.channel.epoll.EpollEventLoop.run(EpollEventLoop.java:366)
# 	at knot//io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at knot//io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "Worker-Main-8" daemon prio=4 Id=108 TIMED_WAITING on java.util.concurrent.ForkJoinPool@440990
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.ForkJoinPool@440990
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.parkUntil(LockSupport.java:410)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.awaitWork(ForkJoinPool.java:1726)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1623)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:165)
#
#
# "IO-Worker-9" prio=5 Id=109 TIMED_WAITING on java.util.concurrent.SynchronousQueue$TransferStack@1112f35c
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.SynchronousQueue$TransferStack@1112f35c
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.parkNanos(LockSupport.java:252)
# 	at java.base@17.0.14/java.util.concurrent.SynchronousQueue$TransferStack.transfer(SynchronousQueue.java:401)
# 	at java.base@17.0.14/java.util.concurrent.SynchronousQueue.poll(SynchronousQueue.java:903)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.getTask(ThreadPoolExecutor.java:1061)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1122)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:635)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "IO-Worker-10" prio=5 Id=110 TIMED_WAITING on java.util.concurrent.SynchronousQueue$TransferStack@1112f35c
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.SynchronousQueue$TransferStack@1112f35c
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.parkNanos(LockSupport.java:252)
# 	at java.base@17.0.14/java.util.concurrent.SynchronousQueue$TransferStack.transfer(SynchronousQueue.java:401)
# 	at java.base@17.0.14/java.util.concurrent.SynchronousQueue.poll(SynchronousQueue.java:903)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.getTask(ThreadPoolExecutor.java:1061)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1122)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:635)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "IO-Worker-11" prio=5 Id=111 TIMED_WAITING on java.util.concurrent.SynchronousQueue$TransferStack@1112f35c
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.SynchronousQueue$TransferStack@1112f35c
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.parkNanos(LockSupport.java:252)
# 	at java.base@17.0.14/java.util.concurrent.SynchronousQueue$TransferStack.transfer(SynchronousQueue.java:401)
# 	at java.base@17.0.14/java.util.concurrent.SynchronousQueue.poll(SynchronousQueue.java:903)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.getTask(ThreadPoolExecutor.java:1061)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1122)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:635)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "IO-Worker-12" prio=5 Id=112 TIMED_WAITING on java.util.concurrent.SynchronousQueue$TransferStack@1112f35c
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.SynchronousQueue$TransferStack@1112f35c
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.parkNanos(LockSupport.java:252)
# 	at java.base@17.0.14/java.util.concurrent.SynchronousQueue$TransferStack.transfer(SynchronousQueue.java:401)
# 	at java.base@17.0.14/java.util.concurrent.SynchronousQueue.poll(SynchronousQueue.java:903)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.getTask(ThreadPoolExecutor.java:1061)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1122)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:635)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "IO-Worker-13" prio=5 Id=113 TIMED_WAITING on java.util.concurrent.SynchronousQueue$TransferStack@1112f35c
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.SynchronousQueue$TransferStack@1112f35c
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.parkNanos(LockSupport.java:252)
# 	at java.base@17.0.14/java.util.concurrent.SynchronousQueue$TransferStack.transfer(SynchronousQueue.java:401)
# 	at java.base@17.0.14/java.util.concurrent.SynchronousQueue.poll(SynchronousQueue.java:903)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.getTask(ThreadPoolExecutor.java:1061)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1122)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:635)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "Worker-Main-14" daemon prio=4 Id=114 RUNNABLE
# 	at knot//net.minecraft.class_6916$class_6932.method_40464(class_6916.java:270)
# 	at knot//net.minecraft.class_6916$class_6917.method_40464(class_6916.java:1119)
# 	at knot//net.minecraft.class_6916$class_6932.method_40464(class_6916.java:270)
# 	at knot//net.minecraft.class_6916$class_6917.method_40464(class_6916.java:1121)
# 	at knot//net.minecraft.class_6916$class_6933.method_40464(class_6916.java:723)
# 	at knot//net.minecraft.class_6916$class_6917.method_40470(class_6916.java:1164)
# 	at knot//net.minecraft.class_6916$class_6917.method_40470(class_6916.java:1145)
# 	at knot//net.minecraft.class_6568.method_38362(class_6568.java:359)
# 	...
#
#
# "Worker-Main-15" daemon prio=4 Id=115 TIMED_WAITING on java.util.concurrent.ForkJoinPool@440990
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.ForkJoinPool@440990
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.parkUntil(LockSupport.java:410)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.awaitWork(ForkJoinPool.java:1726)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1623)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:165)
#
#
# "Worker-Main-16" daemon prio=4 Id=116 RUNNABLE
# 	at knot//net.minecraft.class_6916$class_6933.method_40470(class_6916.java:729)
# 	at knot//net.minecraft.class_6568$class_5917.method_40470(class_6568.java:651)
# 	at knot//net.minecraft.class_6568.method_40532(class_6568.java:288)
# 	at knot//net.minecraft.class_6568.method_38339(class_6568.java:312)
# 	at knot//net.minecraft.class_3754.method_33754(class_3754.java:347)
# 	at knot//net.minecraft.class_3754.method_38332(class_3754.java:313)
# 	at knot//net.minecraft.class_3754$$Lambda$30964/0x0000786c538c7398.get(Unknown Source)
# 	at java.base@17.0.14/java.util.concurrent.CompletableFuture$AsyncSupply.run(CompletableFuture.java:1768)
# 	...
#
#
# "Worker-Main-17" daemon prio=4 Id=117 TIMED_WAITING on java.util.concurrent.ForkJoinPool@440990
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.ForkJoinPool@440990
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.parkUntil(LockSupport.java:410)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.awaitWork(ForkJoinPool.java:1726)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1623)
# 	at java.base@17.0.14/java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:165)
#
#
# "IO-Worker-18" prio=5 Id=118 TIMED_WAITING on java.util.concurrent.SynchronousQueue$TransferStack@1112f35c
# 	at java.base@17.0.14/jdk.internal.misc.Unsafe.park(Native Method)
# 	-  waiting on java.util.concurrent.SynchronousQueue$TransferStack@1112f35c
# 	at java.base@17.0.14/java.util.concurrent.locks.LockSupport.parkNanos(LockSupport.java:252)
# 	at java.base@17.0.14/java.util.concurrent.SynchronousQueue$TransferStack.transfer(SynchronousQueue.java:401)
# 	at java.base@17.0.14/java.util.concurrent.SynchronousQueue.poll(SynchronousQueue.java:903)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.getTask(ThreadPoolExecutor.java:1061)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1122)
# 	at java.base@17.0.14/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:635)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
#
#
# "Async-profiler Timer" daemon prio=5 Id=119 RUNNABLE (in native)
#
#
#
# Stacktrace:
# 	at knot//MC//net.minecraft.server.dedicated.DedicatedServerWatchdog.run(DedicatedServerWatchdog.java:63)
# 	at java.base@17.0.14/java.lang.Thread.run(Thread.java:840)
# Mixins in Stacktrace: None found
#
# -- Performance stats --
# Details:
# 	Random tick rate: 3
# 	Level stats: ResourceKey[minecraft:dimension / minecraft:overworld]: players: 1, entities: 299,299,115,614,614,0,0 [minecraft:falling_block:117,minecraft:item:31,minecraft:cod:24,minecraft:zombie:21,minecraft:skeleton:12], block_entities: 82 [<lithium_sleeping>:46,minecraft:mob_spawner:17,swampier_swamps:decaying_kelp:8,minecraft:campfire:6,minecraft:furnace:3], block_ticks: 1820, fluid_ticks: 114, chunk_source: Chunks[S] W: 2397 E: 299,299,115,614,614,0,0,
# ResourceKey[minecraft:dimension / minecells:black_bridge]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / ad_astra:earth_orbit]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / prominent:vaaz_volcano]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / prominent:cinderstone_depths]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / ad_astra:glacio]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / minecells:prison]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / minecraft:the_nether]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / ad_astra:moon_orbit]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / ad_astra:mars_orbit]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / minecells:ramparts]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / ad_astra:mercury]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / ad_astra:mercury_orbit]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / minecells:promenade]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / ad_astra:venus]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / deeperdarker:otherside]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / minecells:insufferable_crypt]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / spellbladenext:glassocean]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / ad_astra:moon]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / ad_astra:mars]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / ad_astra:venus_orbit]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / minecraft:the_end]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / the_bumblezone:the_bumblezone]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / ad_astra:glacio_orbit]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0,
# ResourceKey[minecraft:dimension / ae2:spatial_storage]: players: 0, entities: 0,0,0,0,0,0,0 [], block_entities: 0 [], block_ticks: 0, fluid_ticks: 0, chunk_source: Chunks[S] W: 0 E: 0,0,0,0,0,0,0
#
# -- System Details --
# Details:
# 	Minecraft Version: 1.20.1
# 	Minecraft Version ID: 1.20.1
# 	Operating System: Linux (amd64) version 6.1.85+
# 	Java Version: 17.0.14, Eclipse Adoptium
# 	Java VM Version: OpenJDK 64-Bit Server VM (mixed mode, sharing), Eclipse Adoptium
# 	Memory: 6679974912 bytes (6370 MiB) / 8589934592 bytes (8192 MiB) up to 10737418240 bytes (10240 MiB)
# 	CPUs: 2
# 	Processor Vendor: GenuineIntel
# 	Processor Name: Intel(R) Xeon(R) CPU @ 2.20GHz
# 	Identifier: Intel64 Family 6 Model 79 Stepping 0
# 	Microarchitecture: Broadwell (Server)
# 	Frequency (GHz): 2.20
# 	Number of physical packages: 1
# 	Number of physical CPUs: 1
# 	Number of logical CPUs: 2
# 	Graphics card #0 name: unknown
# 	Graphics card #0 vendor: unknown
# 	Graphics card #0 VRAM (MB): 0.00
# 	Graphics card #0 deviceId: unknown
# 	Graphics card #0 versionInfo: unknown
# 	Virtual memory max (MB): 6489.48
# 	Virtual memory used (MB): 4832.06
# 	Swap memory total (MB): 0.00
# 	Swap memory used (MB): 0.00
# 	JVM Flags: 2 total; -Xmx10G -Xms8G
# 	Fabric Mods:
# 		aaa_particles: AAAParticles 1.20.1-1.4.7
# 		accessories: Accessories 1.0.0-beta.41+1.20.1
# 			io_wispforest_endec: endec 0.1.8
# 			io_wispforest_endec_gson: gson 0.1.5
# 			io_wispforest_endec_netty: netty 0.1.4
# 		ad_astra: Ad Astra 1.15.5
# 		ad_astra_giselle_addon: Ad Astra: Giselle Addon 5.6
# 		advancednetherite: Advanced Netherite 2.0.2-1.20.1
# 		adventurez: AdventureZ 1.4.20
# 		ae2: Applied Energistics 2 15.2.12
# 			team_reborn_energy: Energy 3.0.0
# 		ae2wtlib: AE2WTLib 15.2.1-fabric
# 		alloy_forgery: Alloy Forgery 2.1.1+1.20
# 		allthetrims: AllTheTrims 3.4.2
# 		almostunified: AlmostUnified 1.20.1-0.9.4
# 		alternate-current: Alternate Current 1.7.0
# 		amendments: Amendments 1.20-1.2.11
# 		animal_feeding_trough: Animal Feeding Trough 1.0.3+1.20.1
# 		appleskin: AppleSkin 2.5.1+mc1.20
# 		aquamirae: Aquamirae 6
# 		aqupdcaracal: Caracal mob 1.20-2.3.3
# 		archers: Archers (RPG Series) 1.3.0+1.20.1
# 			com_github_zsoltmolnarrr_tinyconfig: TinyConfig 2.3.2
# 		archers_expansion: Archers Expansion 0.2.1-1.20.1
# 		architectury: Architectury 9.2.14
# 		archon: Archon 0.7.4
# 			omega-config: OmegaConfig 1.4.0+1.20.1
# 			saflib: SafLib 1.1.0
# 		artifacts: Artifacts 9.5.5
# 			expandability: ExpandAbility 9.0.4
# 			step-height-entity-attribute: Step Height Entity Attribute 1.2.0
# 		ash_api: Ash API 3.0.2+1.20.1
# 		athena: Athena 3.1.1
# 		attributefix: AttributeFix 21.0.4
# 		autotag-convention: AutoTag Convention 2.0.2+1.20
# 			autotag: AutoTag 2.0.2+1.20
# 		azurelib: AzureLib 2.0.6
# 		azurelibarmor: AzureLib Armor 2.0.0
# 		badpackets: Bad Packets 0.4.3
# 		balm-fabric: Balm 7.3.9
# 			kuma_api: KumaAPI 20.1.8
# 		barteringstation: Bartering Station 8.0.0
# 		bcc: BetterCompatibilityChecker 4.0.8
# 		bclib: BCLib 3.0.14
# 			wunderlib: WunderLib 1.1.5
# 		beachparty: Beachparty 1.1.3
# 		beekeeperhut: Friends&Foes - Beekeeper Hut 1.3.0
# 		better-trim-tooltips: Better Trim Tooltips 1.0.1
# 		betterarcheology: Better Archeology 1.1.0
# 		betterchunkloading: Better chunk loading mod 1.20.1-2.3
# 		bettercombat: Better Combat 1.8.3+1.20.1
# 		betterdeserttemples: YUNG's Better Desert Temples 1.20-Fabric-3.0.3
# 			org_reflections_reflections: reflections 0.10.2
# 		betterdungeons: YUNG's Better Dungeons 1.20-Fabric-4.0.3
# 		betterend: Better End 4.0.11
# 		betterend-crashed-ships: BetterEnd Crashed Ships 1.0.0
# 		betterendisland: YUNG's Better End Island 1.20-Fabric-2.0.4
# 		betterfortresses: YUNG's Better Nether Fortresses 1.20-Fabric-2.0.5
# 		betterfpsdist: Better FPS distance Mod 1.20.1-4.0
# 		betterjungletemples: YUNG's Better Jungle Temples 1.20-Fabric-2.0.4
# 		bettermineshafts: YUNG's Better Mineshafts 1.20-Fabric-4.0.4
# 		betternether: Better Nether 9.0.10
# 		betteroceanmonuments: YUNG's Better Ocean Monuments 1.20-Fabric-3.0.4
# 		betterstats: Better Statistics Screen 3.5.2+fabric-1.20.1
# 			tcdcommons: TCD Commons API 3.5+fabric-1.20.1
# 		betterstrongholds: YUNG's Better Strongholds 1.20-Fabric-4.0.3
# 		betterthanmending: BetterThanMending 1.3.0
# 		bettertrims: BetterTrims 2.3.2
# 		betterwitchhuts: YUNG's Better Witch Huts 1.20-Fabric-3.0.3
# 		bewitchment: Bewitchment 1.20-8
# 			impersonate: Impersonate 2.10.2
# 			playerabilitylib: Pal 1.8.0
# 			reach-entity-attributes: Reach Entity Attributes 2.4.0
# 			terraform-wood-api-v1: Terraform Wood API (v1) 7.0.3
# 		blockrunner: Block Runner 8.0.2
# 		blockswap: Block Swap 5.0.0.0
# 		boatbreakfix: Boat Break Fix 1.0.2
# 		bookshelf: Bookshelf 20.1.6
# 		bosses_of_mass_destruction: Bosses of Mass Destruction (Beta) 1.7.5-1.20.1
# 			maelstrom_library: Maelstrom Library 1.6.1-1.20
# 			multipart_entities: MultipartEntities 1.5-1.20
# 		botania: Botania 1.20.1-446-FABRIC
# 			fiber: fiber 0.23.0-2
# 		botarium: Botarium 2.3.3
# 		brewery: Brewery 1.1.4
# 		buildguide: Build Guide 0.4.0
# 		cardinal-components: Cardinal Components API 5.2.2
# 			cardinal-components-block: Cardinal Components API (blocks) 5.2.2
# 			cardinal-components-chunk: Cardinal Components API (chunks) 5.2.2
# 			cardinal-components-item: Cardinal Components API (items) 5.2.2
# 			cardinal-components-level: Cardinal Components API (world saves) 5.2.2
# 			cardinal-components-scoreboard: Cardinal Components API (scoreboard) 5.2.2
# 			cardinal-components-world: Cardinal Components API (worlds) 5.2.2
# 		carryon: Carry On 2.1.2.7
# 		chefsdelight: Chefs Delight 1.0.3-fabric-1.20.1
# ...
# [11:54:04] [main/INFO]: Config for elocindev.prominent_talents.config.Config read successfully.
# [11:54:04] [main/INFO]: Registered Prominent Talents Sounds
# [11:54:04] [main/INFO]: File exists, reading config for elocindev.protbalancer.config.ProtectionBalancerConfig.
# [11:54:04] [main/INFO]: Config for elocindev.protbalancer.config.ProtectionBalancerConfig read successfully.
# [11:54:04] [main/INFO]: Constructing common components for puzzlesapi:iteminteractions
# [11:54:04] [main/INFO]: Constructing common components for puzzlesapi:slotcycling
# [11:54:04] [main/INFO]: Constructing common components for puzzlesapi:limitlesscontainers
# [11:54:05] [main/INFO]: Constructing common components for puzzleslib:main
# [11:54:05] [main/INFO]: Registered bogey styles from railways
# [11:54:06] [main/INFO]: Registering data fixers
# [11:54:06] [main/INFO]: 0 Datafixer optimizations took 8 milliseconds
# [11:54:06] [main/INFO]: Registering tracks for Hex Casting
# [11:54:06] [main/INFO]: Registering tracks for Oh The Biomes You'll Go
# [11:54:06] [main/INFO]: Registering tracks for Blue Skies
# [11:54:06] [main/INFO]: Registering tracks for Twilight Forest
# [11:54:06] [main/INFO]: Registering tracks for Biomes O' Plenty
# [11:54:06] [main/INFO]: Registering tracks for Nature's Spirit
# [11:54:06] [main/INFO]: Registering tracks for Dreams and Desires
# [11:54:06] [main/INFO]: Registering tracks for Quark
# [11:54:06] [main/INFO]: Registering tracks for TerraFirmaCraft
# [11:54:07] [main/INFO]: Reacharound Initializing.
# [11:54:07] [main/INFO]: Reacharound Initialized.
# [11:54:07] [main/INFO]: File exists, reading config for elocindev.rebalance.config.ReBalanceConfig.
# [11:54:07] [main/INFO]: Config for elocindev.rebalance.config.ReBalanceConfig read successfully.
# [11:54:07] [main/INFO]: [Regions Unexplored] generating and loading config
# [11:54:10] [main/INFO]: File exists, reading config for elocindev.resistance_balancer.config.ResistanceBalancerConfig.
# [11:54:10] [main/INFO]: Config for elocindev.resistance_balancer.config.ResistanceBalancerConfig read successfully.
# [11:54:10] [main/INFO]: Hello Fabric world!
# [11:54:10] [main/INFO]: [Fabric Seasons] Trying to read config file...
# [11:54:10] [main/INFO]: [Fabric Seasons] A config file was found, loading it..
# [11:54:10] [main/INFO]: [Fabric Seasons] Successfully loaded config file.
# [11:54:10] [main/INFO]: [Fabric Seasons] Successfully loaded seasonscroptopiacompat 1.0 for croptopia 2.2.2
# [11:54:10] [main/INFO]: [Fabric Seasons] Successfully loaded seasonsdelightcompat 1.0 for farmersdelight 1.3.9
# [11:54:10] [main/INFO]: Shield API initialized!
# [11:54:10] [main/INFO]: File exists, reading config for elocin.shield_overhaul.config.server.ShieldConfig.
# [11:54:10] [main/INFO]: Config for elocin.shield_overhaul.config.server.ShieldConfig read successfully.
# [11:54:10] [main/INFO]: Shield Overhaul's Config Loaded!
# [11:54:11] [main/INFO]: Registering Items for simplyskills
# [11:54:11] [main/INFO]: Registering Entities for simplyskills
# [11:54:12] [main/INFO]: Registering Eldritch End compat Items for simplyswords
# [11:54:12] [main/INFO]: [STDOUT]: Copied from /data/simplyswords/safeload_recipes/eldritch_end/dreadtide.json to /data/simplyswords/recipes/eldritch_end/dreadtide.json
# [11:54:12] [main/INFO]: [STDOUT]: /content/drive/MyDrive/Minecraft-server_Prominence_II_RPG_Hasturian_Era/config
# [11:54:12] [main/INFO]: Hello Fabric world!
# [11:54:13] [main/INFO]: Loading Configs for Sortilege
# [11:54:13] [main/INFO]: Couldn't find config value for path : "[death, glowing_killer]", defaulting to true
# [11:54:13] [main/INFO]: Config initialized!
# [11:54:13] [main/INFO]: Successfully initialized Geckolib!
# [11:54:13] [main/INFO]: Successfully registered SoulsWeapons content!
# [11:54:13] [main/INFO]: Successfully registered built-in 2D model resourcepack!
# [11:54:13] [main/INFO]: Successfully registered built-in Legacy 2D Models resourcepack!
# [11:54:13] [main/INFO]: Successfully registered built-in Legacy 3D Models resourcepack!
# [11:54:13] [main/INFO]: Successfully registered built-in Fresh Animations Compat. resourcepack!
# [11:54:13] [main/INFO]: Initializing done, time taken: 593ms
# [11:54:13] [main/INFO]: Spell Engine x Open Parties and Claims
# [11:54:14] [main/INFO]: Hello Fabric world!
# [11:54:14] [main/INFO]: Creating asynchronous mapping cache executor...
# [11:54:14] [Mappings Cache Thread #1/INFO]: Verifying cache of yarn mappings...
# [11:54:14] [Mappings Cache Thread #1/INFO]: Latest build for yarn is already cached (1 hour(s) ago, refresh in 47 hour(s))
# [11:54:14] [Mappings Cache Thread #1/INFO]: Mappings for yarn build 1.20.1+build.10 are already downloaded
# [11:54:14] [Mappings Cache Thread #1/INFO]: Verified cache of yarn mappings (took 18ms)
# [11:54:14] [Mappings Cache Thread #1/INFO]: Parsing yarn mappings...
# [11:54:14] [main/INFO]: Constructing common components for stoneworks:main
# [11:54:14] [main/INFO]: Loading common config for stoneworks
# [11:54:14] [Thread-3/INFO]: Reloading common config for stoneworks
# [11:54:14] [Thread-3/INFO]: Reloading common config for stoneworks
# [11:54:14] [main/INFO]: structureessentials mod initialized
# [11:54:15] [Mappings Cache Thread #1/INFO]: Parsed yarn mappings (took 972ms)
# [11:54:15] [Mappings Cache Thread #1/INFO]: Caching yarn mappings...
# [11:54:15] [main/INFO]: Loaded config supplementaries-common.json
# [11:54:15] [Mappings Cache Thread #1/INFO]: Cached yarn mappings (took 183ms)
# [11:54:15] [Mappings Cache Thread #1/INFO]: Cached mappings have been built (took 1191ms)
# [11:54:15] [Mappings Cache Thread #1/INFO]:   Classes: 6741
# [11:54:15] [Mappings Cache Thread #1/INFO]:   Methods: 24982
# [11:54:15] [Mappings Cache Thread #1/INFO]:   Fields: 28829
# [11:54:15] [Thread-10/INFO]: Shutting down asynchronous mapping cache executor...
# [11:54:15] [Thread-10/INFO]: Injecting into root logger...
# [11:54:17] [main/INFO]: TechReborn setup done!
# [11:54:17] [main/INFO]: Registered region minecraft:overworld to index 0 for type OVERWORLD
# [11:54:17] [main/INFO]: Registered region minecraft:nether to index 0 for type NETHER
# [11:54:17] [main/INFO]: Registered region regions_unexplored:primary to index 1 for type OVERWORLD
# [11:54:17] [main/INFO]: Registered region regions_unexplored:secondary to index 2 for type OVERWORLD
# [11:54:17] [main/INFO]: Registered region regions_unexplored:nether to index 1 for type NETHER
# [11:54:17] [main/INFO]: Registered region riverredux:overworld to index 3 for type OVERWORLD
# [11:54:18] [main/WARN]: Registering builtin Fabric Seasons integration with Thermoo. Note that this integration will be removed as a builtin feature in the future.
# [11:54:18] [main/INFO]: Creating environment manager EnvironmentManager{controller=com.github.thedeathlycow.thermoo.api.temperature.EmptyEnvironmentController}
# [11:54:18] [main/INFO]: Thermoo initialized
# [11:54:18] [main/INFO]: File exists, reading config for elocindev.tierify.config.CommonConfig.
# [11:54:18] [main/INFO]: Config for elocindev.tierify.config.CommonConfig read successfully.
# [11:54:18] [main/INFO]: Constructing common components for tinyskeletons:main
# [11:54:18] [main/INFO]: Constructing common components for tradingpost:main
# [11:54:19] [main/INFO]: Registered the FluidEffect with Unique ID of minecraft:water for Water (Fluid Amount Required: 81000) with the ID 0
# [11:54:19] [main/INFO]: Registered the FluidEffect with Unique ID of minecraft:lava for Lava (Fluid Amount Required: 81000) with the ID 1
# [11:54:19] [main/INFO]: Registered the FluidEffect with Unique ID of travelersbackpack:potion for block.travelersbackpack.potion_still (Fluid Amount Required: 27000) with the ID 2
# [11:54:19] [main/INFO]: Registered the FluidEffect with Unique ID of minecraft:milk for Air (Fluid Amount Required: 81000) with the ID 3
# [11:54:19] [main/INFO]: [STDOUT]: TxniLib onInitialize!!
# [11:54:19] [main/INFO]: [Collective] JSON file 'entity_names.json' generation requested by mod 'villagernames'.
# [11:54:19] [main/INFO]: Registered JSON trade offer adapter.
# [11:54:19] [main/INFO]: Constructing common components for visualworkbench:main
# [11:54:19] [main/INFO]: [STDOUT]: Config updated!
# [11:54:19] [main/INFO]: [STDOUT]: Config loaded!
# [11:54:19] [main/INFO]: Registering C2S receiver with id wands:key_packet
# [11:54:19] [main/INFO]: Registering C2S receiver with id wands:palette_packet
# [11:54:19] [main/INFO]: Registering C2S receiver with id wands:wand_packet
# [11:54:19] [main/INFO]: Registering C2S receiver with id wands:pos_packet
# [11:54:19] [main/INFO]: Registering C2S receiver with id wands:global_settings_packet
# [11:54:20] [main/INFO]: File exists, reading config for elocindev.ysns.config.DisabledEntities.
# [11:54:20] [main/INFO]: Config for elocindev.ysns.config.DisabledEntities read successfully.
# [11:54:20] [main/INFO]: File exists, reading config for elocindev.ysns.config.PerDimensionEntities.
# [11:54:20] [main/INFO]: Config for elocindev.ysns.config.PerDimensionEntities read successfully.
# [11:54:20] [main/INFO]: You Shall Not Spawn's Config initialized
# [11:54:20] [main/INFO]: Reflections took 9 ms to scan 1 urls, producing 1 keys and 4 values
# [11:54:20] [main/INFO]: Reflections took 8 ms to scan 1 urls, producing 1 keys and 4 values
# [11:54:20] [main/INFO]: Reflections took 2 ms to scan 1 urls, producing 1 keys and 2 values
# [11:54:20] [main/INFO]: Reflections took 4 ms to scan 1 urls, producing 1 keys and 2 values
# [11:54:23] [main/INFO]: Registering content
# [11:54:24] [main/INFO]: Registered extendedae config for auto-sync function
# [11:54:24] [main/INFO]: Initialised items.
# [11:54:24] [main/INFO]: Initialised blocks.
# [11:54:24] [main/INFO]: Initialised block entities.
# [11:54:24] [main/INFO]: Initialised AE2WT integration.
# [11:54:25] [main/INFO]: Initializing 'Better Statistics Screen' as 'BetterStatsServer'.
# [11:54:25] [main/INFO]: Its Morbin' time
# [11:54:25] [main/INFO]: Initialized Frostiful server!
# [11:54:25] [main/INFO]: Krypton is now accelerating your Minecraft server's networking stack 🚀
# [11:54:25] [main/INFO]: [STDOUT]: [Modpack Update Checker] Registered commands
# [11:54:26] [main/INFO]: Initialized block sets in 152ms
# [11:54:26] [main/INFO]: Loaded config dummmmmmy-common.json
# [11:54:26] [main/INFO]: Initialized color sets in 485ms
# [11:54:27] [main/INFO]: Finished mod setup in: [52, 2, 0, 3, 0, 1, 42, 41, 3] ms
# [11:54:27] [main/INFO]: Loading Open Parties and Claims!
# [11:54:27] [main/INFO]: File exists, reading config for elocindev.prominent.config.ServerConfig.
# [11:54:27] [main/INFO]: Config for elocindev.prominent.config.ServerConfig read successfully.
# [11:54:27] [main/INFO]: Initializing 'TCD Commons API' 3.5+fabric-1.20.1 as 'TCDCommonsServer'.
# [11:54:27] [main/INFO]: Loading Xaero's Minimap - Stage 1/2 (Server)
# [11:54:27] [main/INFO]: Loading Xaero's World Map - Stage 1/2 (Server)
# [11:54:28] [main/INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [11:54:28] [main/INFO]: [DataFixerAPI] World Patches are disabled
# [11:54:29] [main/INFO]: Generated runtime SERVER_DATA for pack Supplementaries Generated Pack (supplementaries) in: 84 ms
# [11:54:29] [main/INFO]: [bclib] Did not manage biome betterend:empty_aurora_cave
# [11:54:29] [main/INFO]: [bclib] Did not manage biome betterend:empty_end_cave
# [11:54:29] [main/INFO]: [bclib] Did not manage biome betterend:empty_smaragdant_cave
# [11:54:29] [main/INFO]: [bclib] Did not manage biome betterend:jade_cave
# [11:54:29] [main/INFO]: [bclib] Did not manage biome betterend:lush_aurora_cave
# [11:54:29] [main/INFO]: [bclib] Did not manage biome betterend:lush_smaragdant_cave
# [11:54:29] [main/INFO]: [bclib] Did not manage biome betterend:megalake_grove
# [11:54:29] [main/INFO]: [bclib] Did not manage biome betterend:neon_oasis
# [11:54:29] [main/INFO]: [bclib] Did not manage biome betterend:painted_mountains
# [11:54:33] [main/INFO]: [bclib] Updating Pickers for BCLib - The End  BiomeSource (1eedd729)
# [11:54:33] [main/INFO]: [bclib] Unable to build Biome List yet
# [11:54:33] [main/INFO]: [bclib] No Void Biomes found. Disabling by using barrens
# [11:54:33] [main/INFO]: [bclib] No Barrens Biomes found. Disabling by using land Biomes
# [11:54:33] [main/WARN]: [bclib] No Center Island Biomes found. Forcing use of vanilla center.
# [11:54:33] [main/INFO]: [bclib] Make sure features are loaded from terrablender:org.betterx.bclib.api.v2.generator.BCLibEndBiomeSource
# [11:54:33] [main/INFO]: [bclib] Updating Pickers for BCLib - Nether BiomeSource (69d3cb09)
# [11:54:33] [main/INFO]: [bclib] Unable to build Biome List yet
# [11:54:33] [main/INFO]: [bclib] Make sure features are loaded from terrablender:org.betterx.bclib.api.v2.generator.BCLibNetherBiomeSource
# [11:54:33] [main/INFO]: [bclib] Updating Pickers for BCLib - The End  BiomeSource (6ec3b10)
# [11:54:33] [main/INFO]: [bclib] Unable to build Biome List yet
# [11:54:33] [main/INFO]: [bclib] No Void Biomes found. Disabling by using barrens
# [11:54:33] [main/INFO]: [bclib] No Barrens Biomes found. Disabling by using land Biomes
# [11:54:33] [main/WARN]: [bclib] No Center Island Biomes found. Forcing use of vanilla center.
# [11:54:33] [main/INFO]: [bclib] Make sure features are loaded from terrablender:org.betterx.bclib.api.v2.generator.BCLibEndBiomeSource
# [11:54:33] [main/INFO]: [bclib] Updating Pickers for BCLib - Nether BiomeSource (2359719a)
# [11:54:33] [main/INFO]: [bclib] Unable to build Biome List yet
# [11:54:33] [main/INFO]: [bclib] Make sure features are loaded from terrablender:org.betterx.bclib.api.v2.generator.BCLibNetherBiomeSource
# [11:54:33] [main/INFO]: [bclib] Updating Pickers for BCLib - The End  BiomeSource (16321c89)
# [11:54:33] [main/INFO]: [bclib] Unable to build Biome List yet
# [11:54:33] [main/INFO]: [bclib] No Void Biomes found. Disabling by using barrens
# [11:54:33] [main/INFO]: [bclib] No Barrens Biomes found. Disabling by using land Biomes
# [11:54:33] [main/WARN]: [bclib] No Center Island Biomes found. Forcing use of vanilla center.
# [11:54:33] [main/INFO]: [bclib] Make sure features are loaded from terrablender:org.betterx.bclib.api.v2.generator.BCLibEndBiomeSource
# [11:54:33] [main/INFO]: [bclib] Updating Pickers for BCLib - Nether BiomeSource (78cefc05)
# [11:54:33] [main/INFO]: [bclib] Unable to build Biome List yet
# [11:54:33] [main/INFO]: [bclib] Make sure features are loaded from terrablender:org.betterx.bclib.api.v2.generator.BCLibNetherBiomeSource
# [11:54:33] [main/INFO]: [bclib] Updating Pickers for BCLib - The End  BiomeSource (40eb3c9)
# [11:54:33] [main/INFO]: [bclib] Unable to build Biome List yet
# [11:54:33] [main/INFO]: [bclib] No Void Biomes found. Disabling by using barrens
# [11:54:33] [main/INFO]: [bclib] No Barrens Biomes found. Disabling by using land Biomes
# [11:54:33] [main/WARN]: [bclib] No Center Island Biomes found. Forcing use of vanilla center.
# [11:54:33] [main/INFO]: [bclib] Make sure features are loaded from terrablender:org.betterx.bclib.api.v2.generator.BCLibEndBiomeSource
# [11:54:33] [main/INFO]: [bclib] Updating Pickers for BCLib - Nether BiomeSource (e8cce68)
# [11:54:33] [main/INFO]: [bclib] Unable to build Biome List yet
# [11:54:33] [main/INFO]: [bclib] Make sure features are loaded from terrablender:org.betterx.bclib.api.v2.generator.BCLibNetherBiomeSource
# [11:54:39] [main/INFO]: [betternether] Freeze Registry[ResourceKey[minecraft:root / worlds_together:worldgen/betterx/surface_rules] (Stable)]
# [11:54:39] [main/INFO]: [betternether] Freeze Registry[ResourceKey[minecraft:root / worlds_together:worldgen/betterx/surface_rules] (Stable)]
# [11:54:39] [main/INFO]: [betternether] Freeze Registry[ResourceKey[minecraft:root / worlds_together:worldgen/betterx/surface_rules] (Stable)]
# [11:54:39] [main/INFO]: [betternether] Freeze Registry[ResourceKey[minecraft:root / worlds_together:worldgen/betterx/surface_rules] (Stable)]
# [11:54:39] [main/WARN]: [bclib] No valid BCLBiome Registry available!
# [11:54:39] [main/WARN]: [bclib] No valid Biome Registry available!
# ^C
# ✅ Minecraft server closed!

# %% [markdown]
# **FAQ - THINGS YOU NEED TO KNOW**
#
# you just need to download playit.gg plugin and from there you can make a static ip.

# %% [markdown]
# open google drive for adding plugins and other files modification.
